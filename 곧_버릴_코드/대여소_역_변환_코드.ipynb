# %%
import pandas as pd
import numpy as np
from tqdm import tqdm

total_bicycle = pd.read_csv('C://Users//gwcat//Downloads//Total_Bicycle.csv')
print('1')
total_bicycle.head(5)
# Out:
# 1
#    Unnamed: 0  index      자전거번호                 대여일시  대여 대여소번호  \
# 0         178    182  SPB-38963  2022-06-01 00:17:09       106
# 1         179    183  SPB-49074  2022-06-01 00:41:18      3123
# 2         180    184  SPB-54595  2022-06-01 01:12:13       497
# 3         181    185  SPB-82472  2022-06-01 01:43:20       114
# 4         182    186  SPB-58359  2022-06-01 00:05:01       135
#
#               대여 대여소명  대여거치대                 반납일시  반납대여소번호      반납대여소명  ...  \
# 0          합정역 7번출구 앞      0  2022-06-01 00:48:48      102  망원역 1번출구 앞  ...
# 1  DMC파크뷰자이1단지 110동 앞      0  2022-06-01 01:14:29      102  망원역 1번출구 앞  ...
# 2           합정동주민센터 앞      0  2022-06-01 01:15:55      102  망원역 1번출구 앞  ...
# 3        홍대입구역 8번출구 앞     99  2022-06-01 01:52:43      102  망원역 1번출구 앞  ...
# 4          명물길 원형무대 앞      0  2022-06-01 01:53:22      102  망원역 1번출구 앞  ...
#
#        대여소 경도  대여소 보관수                                             대여소 주소  \
# ...

# %%
df = pd.read_csv('C://Users//gwcat//Downloads//대여소_역_변환.csv',encoding='CP949')
df2 = pd.read_csv('C://Users//gwcat//Downloads//대여소_역_변환.csv',encoding='CP949')

df.head(5)
# Out:
#    Unnamed: 0                 대여소 Station  Distance
# 0           0          합정역 7번출구 앞      합정  0.001225
# 1           1  DMC파크뷰자이1단지 110동 앞      가좌  0.003915
# 2           2           합정동주민센터 앞      합정  0.002705
# 3           3        홍대입구역 8번출구 앞    홍대입구  0.000967
# 4           4          명물길 원형무대 앞      신촌  0.004578

# %%
df.rename(columns = {'대여소':'대여 대여소명','Station':'대여소근처역','Distance':'대여소Distance'},inplace=True)
del df['Unnamed: 0']
df
# Out:
#                  대여 대여소명  대여소근처역  대여소Distance
# 0             합정역 7번출구 앞      합정     0.001225
# 1     DMC파크뷰자이1단지 110동 앞      가좌     0.003915
# 2              합정동주민센터 앞      합정     0.002705
# 3           홍대입구역 8번출구 앞    홍대입구     0.000967
# 4             명물길 원형무대 앞      신촌     0.004578
# ...                  ...     ...          ...
# 2586             서초케이타운앞   청계산입구     0.010558
# 2587              탑성마을입구   청계산입구     0.011341
# 2588        탑성마을 버스정거장 옆   청계산입구     0.011959
# 2589         염곡동(염통골) 입구  양재시민의숲     0.014311
# 2590   구룡터널 입구(개포1단지아파트)      구룡     0.010880
#
# [2591 rows x 3 columns]

# %%
df2.rename(columns = {'대여소':'반납대여소명','Station':'반납소근처역','Distance':'반납소Distance'},inplace=True)

del df2['Unnamed: 0']
df2
# Out:
#                   반납대여소명  반납소근처역  반납소Distance
# 0             합정역 7번출구 앞      합정     0.001225
# 1     DMC파크뷰자이1단지 110동 앞      가좌     0.003915
# 2              합정동주민센터 앞      합정     0.002705
# 3           홍대입구역 8번출구 앞    홍대입구     0.000967
# 4             명물길 원형무대 앞      신촌     0.004578
# ...                  ...     ...          ...
# 2586             서초케이타운앞   청계산입구     0.010558
# 2587              탑성마을입구   청계산입구     0.011341
# 2588        탑성마을 버스정거장 옆   청계산입구     0.011959
# 2589         염곡동(염통골) 입구  양재시민의숲     0.014311
# 2590   구룡터널 입구(개포1단지아파트)      구룡     0.010880
#
# [2591 rows x 3 columns]

# %%
data = pd.merge(total_bicycle, df, how='left')
data
# Out:
#          Unnamed: 0    index      자전거번호                 대여일시  대여 대여소번호  \
# 0               178      182  SPB-38963  2022-06-01 00:17:09       106
# 1               179      183  SPB-49074  2022-06-01 00:41:18      3123
# 2               180      184  SPB-54595  2022-06-01 01:12:13       497
# 3               181      185  SPB-82472  2022-06-01 01:43:20       114
# 4               182      186  SPB-58359  2022-06-01 00:05:01       135
# ...             ...      ...        ...                  ...       ...
# 4167684     4181916  4196913  SPB-30739  2022-06-28 21:21:40       255
# 4167685     4181917  4196914  SPB-81496  2022-06-29 02:53:22       281
# 4167686     4181918  4196915  SPB-53328  2022-06-29 10:15:15      1961
# 4167687     4181919  4196916  SPB-47475  2022-06-29 14:49:09      1961
# 4167688     4181920  4196917  SPB-30138  2022-06-30 22:24:05      1913
#
#                     대여 대여소명  대여거치대                 반납일시  반납대여소번호  \
# ...

# %%
data = pd.merge(data, df2 , how='left')
data
# Out:
#          Unnamed: 0    index      자전거번호                 대여일시  대여 대여소번호  \
# 0               178      182  SPB-38963  2022-06-01 00:17:09       106
# 1               179      183  SPB-49074  2022-06-01 00:41:18      3123
# 2               180      184  SPB-54595  2022-06-01 01:12:13       497
# 3               181      185  SPB-82472  2022-06-01 01:43:20       114
# 4               182      186  SPB-58359  2022-06-01 00:05:01       135
# ...             ...      ...        ...                  ...       ...
# 4171740     4181916  4196913  SPB-30739  2022-06-28 21:21:40       255
# 4171741     4181917  4196914  SPB-81496  2022-06-29 02:53:22       281
# 4171742     4181918  4196915  SPB-53328  2022-06-29 10:15:15      1961
# 4171743     4181919  4196916  SPB-47475  2022-06-29 14:49:09      1961
# 4171744     4181920  4196917  SPB-30138  2022-06-30 22:24:05      1913
#
#                     대여 대여소명  대여거치대                 반납일시  반납대여소번호  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4171745 entries, 0 to 4171744
# Data columns (total 28 columns):
#  #   Column       Dtype
# ---  ------       -----
#  0   Unnamed: 0   int64
#  1   index        int64
#  2   자전거번호        object
#  3   대여일시         object
#  4   대여 대여소번호     int64
#  5   대여 대여소명      object
#  6   대여거치대        int64
#  7   반납일시         object
#  8   반납대여소번호      int64
#  9   반납대여소명       object
#  10  이용시간         int64
#  11  이용거리         float64
#  12  대여 소재지       object
#  13  대여소 위도       float64
#  14  대여소 경도       float64
#  15  대여소 보관수      float64
#  16  대여소 주소       object
#  17  대여소 동        object
#  18  반납 소재지       object
#  19  반납소 위도       float64
#  20  반납소 경도       float64
#  21  반납소 보관수      float64
#  22  반납소 주소       object
#  23  반납소 동        object
#  24  대여소근처역       object
#  25  대여소Distance  float64
#  26  반납소근처역       object
#  27  반납소Distance  float64
# dtypes: float64(9), int64(6), object(13)
# memory usage: 923.0+ MB

# %%
data.to_csv("data.csv", index = False)
