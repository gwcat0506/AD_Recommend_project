# %%
import pandas as pd
df = pd.read_csv('Bike2.csv', encoding='utf8', index_col=0)
df2 = df
list_dong = df2['동'].unique().tolist()
df2['동'] = df2['동'].map(lambda x: list_dong.index(x))
list_st = df2['대여소근처역'].unique().tolist()
df2['대여소근처역'] = df2['대여소근처역'].map(lambda x: list_st.index(x))
df2['대여일자'] = df2['대여일자'].astype(str)
df2['대여일자'] = df2['대여일자'].str.replace(pat=r'[^\w]', repl=r'', regex=True)
df2['대여일자'] = df2['대여일자'].astype(int)
df2.dtypes
dataset = df2.sample(n=100000)
dataset.shape
# Out:
# (100000, 17)

# %%
data = dataset.sample(frac=0.95, random_state=786)
data_unseen = dataset.drop(data.index)
data.reset_index(inplace=True, drop=True)
data_unseen.reset_index(inplace=True, drop=True)
print('Data for Modeling: ' + str(data.shape))
print('Unseen Data For Predictions: ' + str(data_unseen.shape))
# Out:
# Data for Modeling: (95000, 17)
# Unseen Data For Predictions: (5000, 17)

# %%
data_unseen
# Out:
#           대여일자  대여시간  대여소번호  대여구분코드  성별  연령대코드  이용건수  운동량  이동거리(M)  이용시간(분)  \
# 0     20220620     2   2411       0   2      0     1    1        2        3
# 1     20220614     1   2742       0   1      3     1    1        1        3
# 2     20220604     0    109       1   1      2     1    3        3        3
# 3     20220612     2   2613       0   2      3     1    0        1        1
# 4     20220612     0   1231       0   1      3     1    1        1        1
# ...        ...   ...    ...     ...  ..    ...   ...  ...      ...      ...
# 4995  20220602     1    385       0   0      3     1    0        0        0
# 4996  20220618     2   1653       0   2      3     1    1        1        2
# 4997  20220601     2    240       0   2      4     1    0        0        2
# 4998  20220616     1   1072       0   2      3     1    2        2        2
# 4999  20220620     0   4175       1   1      2     1    3        3        3
#
#       주말  요일  대여소근처역  소재지    동  산업종류  광고
# 0      0   0      98   13  277     5  29
# 1      0   1      35    0   86     0   2
# 2      1   5      93    5  106     4  29
# 3      1   6      54    1   58    11  29
# 4      1   6      40    1  105     7  29
# ...   ..  ..     ...  ...  ...   ...  ..
# 4995   0   3     293   11   46     6  13
# 4996   1   5      59    3    6     2  29
# 4997   0   2     163    2  111     0  29
# 4998   0   3      10    7  279     5  29
# 4999   0   0     169   21  221     9  29
#
# [5000 rows x 17 columns]

# %%
from pycaret.classification import *
exp_clf101 = setup(data = data, target = '광고', session_id=123)
# Out:
# <style type="text/css">
# #T_a8b05_row44_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_a8b05">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a8b05_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_a8b05_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a8b05_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a8b05_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_a8b05_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_a8b05_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_a8b05_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_a8b05_row1_col1" class="data row1 col1" >광고</td>
#     </tr>
#     <tr>
#       <th id="T_a8b05_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_a8b05_row2_col0" class="data row2 col0" >Target Type</td>
#       <td id="T_a8b05_row2_col1" class="data row2 col1" >Multiclass</td>
#     </tr>
#     <tr>
#       <th id="T_a8b05_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_a8b05_row3_col0" class="data row3 col0" >Label Encoded</td>
#       <td id="T_a8b05_row3_col1" class="data row3 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_a8b05_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_a8b05_row4_col0" class="data row4 col0" >Original Data</td>
#       <td id="T_a8b05_row4_col1" class="data row4 col1" >(95000, 17)</td>
#     </tr>
#     <tr>
#       <th id="T_a8b05_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_a8b05_row5_col0" class="data row5 col0" >Missing Values</td>
#       <td id="T_a8b05_row5_col1" class="data row5 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_a8b05_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_a8b05_row6_col0" class="data row6 col0" >Numeric Features</td>
#       <td id="T_a8b05_row6_col1" class="data row6 col1" >5</td>
#     </tr>
#     <tr>
#       <th id="T_a8b05_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_a8b05_row7_col0" class="data row7 col0" >Categorical Features</td>
#       <td id="T_a8b05_row7_col1" class="data row7 col1" >11</td>
#     </tr>
#     <tr>
#       <th id="T_a8b05_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_a8b05_row8_col0" class="data row8 col0" >Ordinal Features</td>
#       <td id="T_a8b05_row8_col1" class="data row8 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_a8b05_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_a8b05_row9_col0" class="data row9 col0" >High Cardinality Features</td>
#       <td id="T_a8b05_row9_col1" class="data row9 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_a8b05_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_a8b05_row10_col0" class="data row10 col0" >High Cardinality Method</td>
#       <td id="T_a8b05_row10_col1" class="data row10 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_a8b05_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_a8b05_row11_col0" class="data row11 col0" >Transformed Train Set</td>
#       <td id="T_a8b05_row11_col1" class="data row11 col1" >(66499, 73)</td>
#     </tr>
#     <tr>
#       <th id="T_a8b05_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_a8b05_row12_col0" class="data row12 col0" >Transformed Test Set</td>
#       <td id="T_a8b05_row12_col1" class="data row12 col1" >(28501, 73)</td>
#     </tr>
#     <tr>
#       <th id="T_a8b05_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_a8b05_row13_col0" class="data row13 col0" >Shuffle Train-Test</td>
#       <td id="T_a8b05_row13_col1" class="data row13 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_a8b05_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_a8b05_row14_col0" class="data row14 col0" >Stratify Train-Test</td>
#       <td id="T_a8b05_row14_col1" class="data row14 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_a8b05_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_a8b05_row15_col0" class="data row15 col0" >Fold Generator</td>
#       <td id="T_a8b05_row15_col1" class="data row15 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_a8b05_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_a8b05_row16_col0" class="data row16 col0" >Fold Number</td>
#       <td id="T_a8b05_row16_col1" class="data row16 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_a8b05_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_a8b05_row17_col0" class="data row17 col0" >CPU Jobs</td>
#       <td id="T_a8b05_row17_col1" class="data row17 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_a8b05_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_a8b05_row18_col0" class="data row18 col0" >Use GPU</td>
#       <td id="T_a8b05_row18_col1" class="data row18 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_a8b05_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_a8b05_row19_col0" class="data row19 col0" >Log Experiment</td>
#       <td id="T_a8b05_row19_col1" class="data row19 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_a8b05_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_a8b05_row20_col0" class="data row20 col0" >Experiment Name</td>
#       <td id="T_a8b05_row20_col1" class="data row20 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_a8b05_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_a8b05_row21_col0" class="data row21 col0" >USI</td>
#       <td id="T_a8b05_row21_col1" class="data row21 col1" >ed86</td>
#     </tr>
#     <tr>
#       <th id="T_a8b05_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_a8b05_row22_col0" class="data row22 col0" >Imputation Type</td>
#       <td id="T_a8b05_row22_col1" class="data row22 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_a8b05_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_a8b05_row23_col0" class="data row23 col0" >Iterative Imputation Iteration</td>
#       <td id="T_a8b05_row23_col1" class="data row23 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_a8b05_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_a8b05_row24_col0" class="data row24 col0" >Numeric Imputer</td>
#       <td id="T_a8b05_row24_col1" class="data row24 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_a8b05_level0_row25" class="row_heading level0 row25" >25</th>
#       <td id="T_a8b05_row25_col0" class="data row25 col0" >Iterative Imputation Numeric Model</td>
#       <td id="T_a8b05_row25_col1" class="data row25 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_a8b05_level0_row26" class="row_heading level0 row26" >26</th>
#       <td id="T_a8b05_row26_col0" class="data row26 col0" >Categorical Imputer</td>
#       <td id="T_a8b05_row26_col1" class="data row26 col1" >constant</td>
#     </tr>
#     <tr>
#       <th id="T_a8b05_level0_row27" class="row_heading level0 row27" >27</th>
#       <td id="T_a8b05_row27_col0" class="data row27 col0" >Iterative Imputation Categorical Model</td>
#       <td id="T_a8b05_row27_col1" class="data row27 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_a8b05_level0_row28" class="row_heading level0 row28" >28</th>
#       <td id="T_a8b05_row28_col0" class="data row28 col0" >Unknown Categoricals Handling</td>
#       <td id="T_a8b05_row28_col1" class="data row28 col1" >least_frequent</td>
#     </tr>
#     <tr>
#       <th id="T_a8b05_level0_row29" class="row_heading level0 row29" >29</th>
#       <td id="T_a8b05_row29_col0" class="data row29 col0" >Normalize</td>
#       <td id="T_a8b05_row29_col1" class="data row29 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_a8b05_level0_row30" class="row_heading level0 row30" >30</th>
#       <td id="T_a8b05_row30_col0" class="data row30 col0" >Normalize Method</td>
#       <td id="T_a8b05_row30_col1" cla

# %%
best_model = compare_models()
# Out:
# <style type="text/css">
# #T_f5afd th {
#   text-align: left;
# }
# #T_f5afd_row0_col0, #T_f5afd_row0_col2, #T_f5afd_row0_col3, #T_f5afd_row0_col4, #T_f5afd_row1_col0, #T_f5afd_row1_col1, #T_f5afd_row1_col3, #T_f5afd_row1_col4, #T_f5afd_row1_col5, #T_f5afd_row1_col6, #T_f5afd_row1_col7, #T_f5afd_row2_col0, #T_f5afd_row2_col1, #T_f5afd_row2_col2, #T_f5afd_row2_col5, #T_f5afd_row2_col6, #T_f5afd_row2_col7, #T_f5afd_row3_col0, #T_f5afd_row3_col1, #T_f5afd_row3_col3, #T_f5afd_row3_col4, #T_f5afd_row3_col5, #T_f5afd_row3_col6, #T_f5afd_row3_col7, #T_f5afd_row4_col0, #T_f5afd_row4_col1, #T_f5afd_row4_col2, #T_f5afd_row4_col3, #T_f5afd_row4_col4, #T_f5afd_row4_col5, #T_f5afd_row4_col6, #T_f5afd_row4_col7, #T_f5afd_row5_col0, #T_f5afd_row5_col1, #T_f5afd_row5_col2, #T_f5afd_row5_col3, #T_f5afd_row5_col4, #T_f5afd_row5_col5, #T_f5afd_row5_col6, #T_f5afd_row5_col7, #T_f5afd_row6_col0, #T_f5afd_row6_col1, #T_f5afd_row6_col2, #T_f5afd_row6_col3, #T_f5afd_row6_col4, #T_f5afd_row6_col5, #T_f5afd_row6_col6, #T_f5afd_row6_col7, #T_f5afd_row7_col0, #T_f5afd_row7_col1, #T_f5afd_row7_col2, #T_f5afd_row7_col3, #T_f5afd_row7_col4, #T_f5afd_row7_col5, #T_f5afd_row7_col6, #T_f5afd_row7_col7, #T_f5afd_row8_col0, #T_f5afd_row8_col1, #T_f5afd_row8_col2, #T_f5afd_row8_col3, #T_f5afd_row8_col4, #T_f5afd_row8_col5, #T_f5afd_row8_col6, #T_f5afd_row8_col7, #T_f5afd_row9_col0, #T_f5afd_row9_col1, #T_f5afd_row9_col2, #T_f5afd_row9_col3, #T_f5afd_row9_col4, #T_f5afd_row9_col5, #T_f5afd_row9_col6, #T_f5afd_row9_col7, #T_f5afd_row10_col0, #T_f5afd_row10_col1, #T_f5afd_row10_col2, #T_f5afd_row10_col3, #T_f5afd_row10_col4, #T_f5afd_row10_col5, #T_f5afd_row10_col6, #T_f5afd_row10_col7, #T_f5afd_row11_col0, #T_f5afd_row11_col1, #T_f5afd_row11_col2, #T_f5afd_row11_col3, #T_f5afd_row11_col4, #T_f5afd_row11_col5, #T_f5afd_row11_col6, #T_f5afd_row11_col7, #T_f5afd_row12_col0, #T_f5afd_row12_col1, #T_f5afd_row12_col2, #T_f5afd_row12_col3, #T_f5afd_row12_col4, #T_f5afd_row12_col5, #T_f5afd_row12_col6, #T_f5afd_row12_col7 {
#   text-align: left;
# }
# #T_f5afd_row0_col1, #T_f5afd_row0_col5, #T_f5afd_row0_col6, #T_f5afd_row0_col7, #T_f5afd_row1_col2, #T_f5afd_row2_col3, #T_f5afd_row2_col4, #T_f5afd_row3_col2 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_f5afd_row0_col8, #T_f5afd_row1_col8, #T_f5afd_row2_col8, #T_f5afd_row3_col8, #T_f5afd_row4_col8, #T_f5afd_row5_col8, #T_f5afd_row6_col8, #T_f5afd_row7_col8, #T_f5afd_row9_col8, #T_f5afd_row10_col8, #T_f5afd_row11_col8, #T_f5afd_row12_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_f5afd_row8_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_f5afd">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f5afd_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_f5afd_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_f5afd_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_f5afd_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_f5afd_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_f5afd_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_f5afd_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_f5afd_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_f5afd_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f5afd_level0_row0" class="row_heading level0 row0" >dt</th>
#       <td id="T_f5afd_row0_col0" class="data row0 col0" >Decision Tree Classifier</td>
#       <td id="T_f5afd_row0_col1" class="data row0 col1" >0.9737</td>
#       <td id="T_f5afd_row0_col2" class="data row0 col2" >0.0955</td>
#       <td id="T_f5afd_row0_col3" class="data row0 col3" >0.8327</td>
#       <td id="T_f5afd_row0_col4" class="data row0 col4" >0.9739</td>
#       <td id="T_f5afd_row0_col5" class="data row0 col5" >0.9737</td>
#       <td id="T_f5afd_row0_col6" class="data row0 col6" >0.9328</td>
#       <td id="T_f5afd_row0_col7" class="data row0 col7" >0.9328</td>
#       <td id="T_f5afd_row0_col8" class="data row0 col8" >0.2010</td>
#     </tr>
#     <tr>
#       <th id="T_f5afd_level0_row1" class="row_heading level0 row1" >et</th>
#       <td id="T_f5afd_row1_col0" class="data row1 col0" >Extra Trees Classifier</td>
#       <td id="T_f5afd_row1_col1" class="data row1 col1" >0.9727</td>
#       <td id="T_f5afd_row1_col2" class="data row1 col2" >0.0965</td>
#       <td id="T_f5afd_row1_col3" class="data row1 col3" >0.7075</td>
#       <td id="T_f5afd_row1_col4" class="data row1 col4" >0.9722</td>
#       <td id="T_f5afd_row1_col5" class="data row1 col5" >0.9722</td>
#       <td id="T_f5afd_row1_col6" class="data row1 col6" >0.9300</td>
#       <td id="T_f5afd_row1_col7" class="data row1 col7" >0.9301</td>
#       <td id="T_f5afd_row1_col8" class="data row1 col8" >2.5590</td>
#     </tr>
#     <tr>
#       <th id="T_f5afd_level0_row2" class="row_heading level0 row2" >nb</th>
#       <td id="T_f5afd_row2_col0" class="data row2 col0" >Naive Bayes</td>
#       <td id="T_f5afd_row2_col1" class="data row2 col1" >0.9725</td>
#       <td id="T_f5afd_row2_col2" class="data row2 col2" >0.0963</td>
#       <td id="T_f5afd_row2_col3" class="data row2 col3" >0.8811</td>
#       <td id="T_f5afd_row2_col4" class="data row2 col4" >0.9767</td>
#       <td id="T_f5afd_row2_col5" class="data row2 col5" >0.9727</td>
#       <td id="T_f5afd_row2_col6" class="data row2 col6" >0.9294</td>
#       <td id="T_f5afd_row2_col7" class="data row2 col7" >0.9295</td>
#       <td id="T_f5afd_row2_col8" class="data row2 col8" >0.3370</td>
#     </tr>
#     <tr>
#       <th id="T_f5afd_level0_row3" class="row_heading level0 row3" >rf</th>
#       <td id="T_f5afd_row3_col0" class="data row3 col0" >Random Forest Classifier</td>
#       <td id="T_f5afd_row3_col1" class="data row3 col1" >0.9698</td>
#       <td id="T_f5afd_row3_col2" class="data row3 col2" >0.0965</td>
#       <td id="T_f5afd_row3_col3" class="data row3 col3" >0.5734</td>
#       <td id="T_f5afd_row3_col4" class="data row3 col4" >0.9679</td>
#       <td id="T_f5afd_row3_col5" class="data row3 col5" >0.9683</td>
#       <td id="T_f5afd_row3_col6" class="data row3 col6" >0.9223</td>
#       <td id="T_f5afd_row3_col7" class="data row3 col7" >0.9223</td>
#       <td id="T_f5afd_row3_col8" class="data row3 col8" >2.5230</td>
#     </tr>
#     <tr>
#       <th id="T_f5afd_level0_row4" class="row_heading level0 row4" >gbc</th>
#       <td id="T_f5afd_row4_col0" class="data row4 col0" >Gradient Boosting Classifier</td>
#       <td id="T_f5afd_row4_col1" class="data row4 col1" >0.9423</td>
#       <td id="T_f5afd_row4_col2" class="data row4 col2" >0.0951</td>
#       <td id="T_f5afd_row4_col3" class="data row4 col3" >0.6160</td>
#       <td id="T_f5afd_row4_col4" class="data row4 col4" >0.9548</td>
#       <td id="T_f5afd_row4_col5" class="data row4 col5" >0.9461</td>
#       <td id="T_f5afd_row4_col6" class="data row4 col6" >0.8601</td>
#       <td id="T_f5afd_row4_col7" class="data row4 col7" >0.8624</td>
#       <td id="T_f5afd_row4_col8" class="data row4 col8" >172.9890</td>
#     </tr>
#     <tr>
#       <th id="T_f5afd_level0_row5" class="row_heading level0 row5" >lda</th>
#       <td id="T_f5afd_row5_col0" class="data row5 col0" >Linear Discriminant Analysis</td>
#       <td id="T_f5afd_row5_col1" class="data row5 col1" >0.8875</td>
#       <td id="T_f5afd_row5_col2" class="data row5 col2" >0.0908</td>
#       <td id="T_f5afd_row5_col3" class="data row5 col3" >0.8162</td>
#       <td id="T_f5afd_row5_col4" class="data row5 col4" >0.9553</td>
#       <td id="T_f5afd_row5_col5" class="data row5 col5" >0.9167</td>
#       <td id="T_f5afd_row5_col6" class="data row5 col6" >0.7420</td>
#       <td id="T_f5afd_row5_col7" class="data row5 col7" >0.7494</td>
#       <td id="T_f5afd_row5_col8" class="data row5 col8" >1.3350</td>
#     </tr>
#     <tr>
#       <th id="T_f5afd_level0_row6" class="row_heading level0 row6" >lr</th>
#       <td id="T_f5afd_row6_col0" class="da

# %%
best_model
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=None, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=123, splitter='best')

# %%
save_model(best_model, 'mymodel2')
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=None,
#           steps=[('dtypes',
#                   DataTypes_Auto_infer(categorical_features=[],
#                                        display_types=True, features_todrop=[],
#                                        id_columns=[],
#                                        ml_usecase='classification',
#                                        numerical_features=[], target='광고',
#                                        time_features=[])),
#                  ('imputer',
#                   Simple_Imputer(categorical_strategy='not_available',
#                                  fill_value_categorical=None,
#                                  fill_value_numerical=None,
#                                  numeric_strategy=...
#                  ('dfs', 'passthrough'), ('pca', 'passthrough'),
#                  ['trained_model',
#                   DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None,
#                                          criterion='gini', max_depth=None,
#                                          max_features=None, max_leaf_nodes=None,
#                                          min_impurity_decrease=0.0,
#                                          min_impurity_split=None,
#                                          min_samples_leaf=1, min_samples_split=2,
#                                          min_weight_fraction_leaf=0.0,
#                                          presort='deprecated', random_state=123,
#                                          splitter='best')]],
#           verbose=False),
#  'mymodel1.pkl')

# %%
# !pip install pycaret[full]
# Out:
# Requirement already satisfied: pycaret[full] in c:\users\smdhk\anaconda3\envs\pycaret\lib\site-packages (2.3.10)
# Requirement already satisfied: seaborn in c:\users\smdhk\anaconda3\envs\pycaret\lib\site-packages (from pycaret[full]) (0.11.2)
# Requirement already satisfied: pandas in c:\users\smdhk\anaconda3\envs\pycaret\lib\site-packages (from pycaret[full]) (1.4.3)
# Requirement already satisfied: nltk in c:\users\smdhk\anaconda3\envs\pycaret\lib\site-packages (from pycaret[full]) (3.7)
# Requirement already satisfied: plotly>=4.4.1 in c:\users\smdhk\anaconda3\envs\pycaret\lib\site-packages (from pycaret[full]) (5.10.0)
# Requirement already satisfied: pyyaml<6.0.0 in c:\users\smdhk\anaconda3\envs\pycaret\lib\site-packages (from pycaret[full]) (5.4.1)
# Requirement already satisfied: pyLDAvis in c:\users\smdhk\anaconda3\envs\pycaret\lib\site-packages (from pycaret[full]) (3.2.2)
# Requirement already satisfied: kmodes>=0.10.1 in c:\users\smdhk\anaconda3\envs\pycaret\lib\site-packages (from pycaret[full]) (0.12.1)
# Requirement already satisfied: matplotlib in c:\users\smdhk\anaconda3\envs\pycaret\lib\site-packages (from pycaret[full]) (3.5.3)
# Requirement already satisfied: lightgbm>=2.3.1 in c:\users\smdhk\anaconda3\envs\pycaret\lib\site-packages (from pycaret[full]) (3.3.2)
# Requirement already satisfied: joblib in c:\users\smdhk\anaconda3\envs\pycaret\lib\site-packages (from pycaret[full]) (1.1.0)
# Requirement already satisfied: numba<0.55 in c:\users\smdhk\anaconda3\envs\pycaret\lib\site-packages (from pycaret[full]) (0.54.1)
# Requirement already satisfied: mlflow in c:\users\smdhk\anaconda3\envs\pycaret\lib\site-packages (from pycaret[full]) (1.28.0)
# Requirement already satisfied: spacy<2.4.0 in c:\users\smdhk\anaconda3\envs\pycaret\lib\site-packages (from pycaret[full]) (2.3.7)
# Requirement already satisfied: scikit-plot in c:\users\smdhk\anaconda3\envs\pycaret\lib\site-packages (from pycaret[full]) (0.3.7)
# Requirement already satisfied: IPython in c:\users\smdhk\anaconda3\envs\pycaret\lib\site-packages (from pycaret[full]) (8.4.0)
# Requirement already satisfied: textblob in c:\users\smdhk\anaconda3\envs\pycaret\lib\site-packages (from pycaret[full]) (0.17.1)
# Requirement already satisfied: cufflinks>=0.17.0 in c:\users\smdhk\anaconda3\envs\pycaret\lib\site-packages (from pycaret[full]) (0.17.3)
# Requirement already satisfied: pyod in c:\users\smdhk\anaconda3\envs\pycaret\lib\site-packages (from pycaret[full]) (1.0.4)
# Requirement already satisfied: umap-learn in c:\users\smdhk\anaconda3\envs\pycaret\lib\site-packages (from pycaret[full]) (0.5.3)
# Requirement already satisfied: mlxtend>=0.17.0 in c:\users\smdhk\anaconda3\envs\pycaret\lib\site-packages (from pycaret[full]) (0.19.0)
# Requirement already satisfied: yellowbrick>=1.0.1 in c:\users\smdhk\anaconda3\envs\pycaret\lib\site-packages (from pycaret[full]) (1.3.post1)
# Requirement already satisfied: scikit-learn==0.23.2 in c:\users\smdhk\anaconda3\envs\pycaret\lib\site-packages (from pycaret[full]) (0.23.2)
# Requirement already satisfied: imbalanced-learn==0.7.0 in c:\users\smdhk\anaconda3\envs\pycaret\lib\site-packages (from pycaret[full]) (0.7.0)
# Requirement already satisfied: scipy<=1.5.4 in c:\users\smdhk\anaconda3\envs\pycaret\lib\site-packages (from pycaret[full]) (1.5.4)
# Requirement already satisfied: wordcloud in c:\users\smdhk\anaconda3\envs\pycaret\lib\site-packages (from pycaret[full]) (1.8.2.2)
# Requirement already satisfied: pandas-profiling>=2.8.0 in c:\users\smdhk\anaconda3\envs\pycaret\lib\site-packages (from pycaret[full]) (3.2.0)
# Requirement already satisfied: gensim<4.0.0 in c:\users\smdhk\anaconda3\envs\pycaret\lib\site-packages (from pycaret[full]) (3.8.3)
# Requirement already satisfied: ipywidgets in c:\users\smdhk\anaconda3\envs\pycaret\lib\site-packages (from pycaret[full]) (8.0.1)
# Requirement already satisfied: Boruta in c:\users\smdhk\anaconda3\envs\pycaret\lib\site-packages (from pycaret[full]) (0.3)
# Collecting fairlearn
#   Using cached fairlearn-0.7.0-py3-none-any.whl (177 kB)
# Collecting catboost>=0.23.2
#   Downloading catboost-1.0.6-cp38-none-win_amd64.whl (73.9 MB)
#      ---------------------------------------- 73.9/73.9 MB 5.8 MB/s eta 0:00:00
# Collecting xgboost>=1.1.0
#   Downloading xgboost-1.6.2-py3-none-win_amd64.whl (125.4 MB)
#      -------------------------------------- 125.4/125.4 MB 2.8 MB/s eta 0:00:00
# Collecting tune-sklearn>=0.2.1
#   Using cached tune_sklearn-0.4.3-py3-none-any.whl (40 kB)
# Collecting explainerdashboard
#   Using cached explainerdashboard-0.4.0-py3-none-any.whl (279 kB)
# Collecting boto3
#   Downloading boto3-1.24.59-py3-none-any.whl (132 kB)
#      -------------------------------------- 132.5/132.5 kB 3.9 MB/s eta 0:00:00
# Collecting m2cgen
#   Using cached m2cgen-0.10.0-py3-none-any.whl (92 kB)
# Collecting gradio
#   Downloading gradio-3.1.7-py3-none-any.whl (6.1 MB)
#      ---------------------------------------- 6.1/6.1 MB 3.2 MB/s eta 0:00:00
# Collecting fastapi
#   Downloading fastapi-0.80.0-py3-none-any.whl (54 kB)
#      ---------------------------------------- 54.8/54.8 kB 3.0 MB/s eta 0:00:00
# Collecting google-cloud-storage
#   Downloading google_cloud_storage-2.5.0-py2.py3-none-any.whl (106 kB)
#      -------------------------------------- 107.0/107.0 kB 6.4 MB/s eta 0:00:00
# Requirement already satisfied: shap in c:\users\smdhk\anaconda3\envs\pycaret\lib\site-packages (from pycaret[full]) (0.41.0)
# Collecting azure-storage-blob
#   Using cached azure_storage_blob-12.13.1-py3-none-any.whl (377 kB)
# Requirement already satisfied: uvicorn in c:\users\smdhk\anaconda3\envs\pycaret\lib\site-packages (from pycaret[full]) (0.18.2)
# Collecting evidently
#   Using cached evidently-0.1.56.dev0-py3-none-any.whl (11.9 MB)
# Collecting scikit-optimize>=0.8.1
#   Using cached scikit_optimize-0.9.0-py2.py3-none-any.whl (100 kB)
# Collecting autoviz
#   Using cached autoviz-0.1.43-py3-none-any.whl (62 kB)
# Collecting optuna>=2.2.0
#   Using cached optuna-2.10.1-py3-none-any.whl (308 kB)
# Collecting hyperopt
#   Using cached hyperopt-0.2.7-py2.py3-none-any.whl (1.6 MB)
# Collecting fugue>=0.6.5
#   Using cached fugue-0.7.1-py3-none-any.whl (299 kB)
# Collecting interpret<=0.2.4
#   Using cached interpret-0.2.4-py3-none-any.whl (1.4 kB)
# Collecting ray[tune]>=1.0.0
#   Downloading ray-2.0.0-cp38-cp38-win_amd64.whl (20.7 MB)
#      ---------------------------------------- 20.7/20.7 MB 2.3 MB/s eta 0:00:00
# Requirement already satisfied: psutil in c:\users\smdhk\anaconda3\envs\pycaret\lib\site-packages (from pycaret[full]) (5.9.1)
# Requirement already satisfied: numpy>=1.13.3 in c:\users\smdhk\anaconda3\envs\pycaret\lib\site-packages (from imbalanced-learn==0.7.0->pycaret[full]) (1.19.5)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\smdhk\anaconda3\envs\pycaret\lib\site-packages (from scikit-learn==0.23.2->pycaret[full]) (3.1.0)
# Collecting graphviz
#   Using cached graphviz-0.20.1-py3-none-any.whl (47 kB)
# Requirement already satisfied: six in c:\users\smdhk\anaconda3\envs\pycaret\lib\site-packages (from catboost>=0.23.2->pycaret[full]) (1.16.0)
# Requirement already satisfied: setuptools>=34.4.1 in c:\users\smdhk\anaconda3\envs\pycaret\lib\site-packages (from cufflinks>=0.17.0->pycaret[full]) (65.1.1)
# Requirement already satisfied: colorlover>=0.2.1 in c:\users\smdhk\anaconda3\envs\pycaret\lib\site-packages (from cufflinks>=0.17.0->pycaret[full]) (0.3.0)
# Requirement already satisfied: sqlalchemy in c:\users\smdhk\anaconda3\envs\pycaret\lib\site-packages (from fugue>=0.6.5->pycaret[full]) (1.4.40)
# Collecting fugue-sql-antlr>=0.1.0
#   Using cached fugue-sql-antlr-0.1.0.tar.gz (173 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting adagio>=0.2.4
#   Using cached adagio-0.2.4-py3-none-any.whl (26 kB)
# Collecting triad>=0.6.6
#   Using cached triad-0.6.7-py3-none-any.whl (64 kB)
# Requirement already satisfied: jinja2 in c:\users\smdhk\anaconda3\envs\pycaret\lib\site-packages (from fugue>=0.6.5->pycaret[full]) (3.1.2)
# Collecting qpd>=0.3.1
#   Using cached qpd-0.3.3-py3-none-any.whl (189 kB)
# Collecting pyarrow>=0.15.1
#   Downloading pyarrow-9.0.0-cp38-cp38-win_amd64.whl (19.6 MB)
#      ---------------------------------------- 19.6/19.6 MB 7.4 MB/s eta 0:00:00
# Requirement already satisfied: smart-open>=1.8.1 in c:\users\smdhk\anaconda3\envs\pycaret\lib\site-packages (from gensim<4.0.0->pycaret[full]) (6.1.0)
# Requirement already satisfied: Cython==0.29.14 in c:\users\smdhk\anaconda3\envs\pycaret\lib\site-packages (from gensim<4.0.0->pycaret[full]) (0.29.14)
# Collecting interpret-core[dash,debug,decisiontree,ebm,lime,linear,notebook,plotly,required,sensitivity,shap,skoperules,treeinterpreter]>=0.2.4
#   Using cached interpret_core-0.2.7-py3-none-any.whl (6.6 MB)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\smdhk\anaconda3\envs\pycaret\lib\site-packages (from IPython->pycaret[full]) (2.13.0)
# Requirement already satisfied: jedi>=0.16 in c:\users\smdhk\anaconda3\envs\pycaret\lib\site-packages (from IPython->pycaret[full]) (0.18.1)
# Requirement already satisfied: decorator in c:\users\smdhk\anaconda3\envs\pycaret\lib\site-packages (from IPython->pycaret[full]) (5.1.1)
# Requirement already satisfied: pickleshare in c:\users\smdhk\anaconda3\envs\pycaret\lib\site-packages (from IPython->pycaret[full]) (0.7.5)
# Requirement already satisfied: traitlets>=5 in c:\users\smdhk\anaconda3\envs\pycaret\lib\site-packages (from IPython->pycaret[full]) (5.3.0)
# Requirement already satisfied: stack-data in c:\users\smdhk\anaconda3\envs\pycaret\lib\site-packages (from IPython->pycaret[full]) (0.4.0)
# Requirement already satisfied: backcall in c:\users\smdhk\anaconda3\envs\pycaret\lib\site-packages (from IPython->pycaret[full]) (0.2.0)
# Requirement already satisfied: colorama in c:\users\smdhk\anaconda3\envs\pycaret\lib\site-packages (from IPython->pycaret[full]) (0.4.5)
# Requirement already satisfied: matplotlib-inline in c:\users\smdhk\anaconda3\envs\pycaret\lib\site-packages (from IPython->pycaret[full]) (0.1.6)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\smdhk\anaconda3\envs\pycaret\lib\site-packages (from IPython->pycaret[full]) (3.0.30)
# Requirement already satisfied: jupyterlab-widgets~=3.0 in c:\users\smdhk\anaconda3\envs\pycaret\lib\site-packages (from ipywidgets->pycaret[full]) (3.0.2)
# Requirement already satisfied: widgetsnbextension~=4.0 in c:\users\smdhk\anaconda3\envs\pycaret\lib\site-packages (from ipywidgets->pycaret[full]) (4.0.2)
# Requirement already satisfied: ipykernel>=4.5.1 in c:\users\smdhk\anaconda3\envs\pycaret\lib\site-packages (from ipywidgets->pycaret[full]) (6.15.1)
# Requirement already satisfied: wheel in c:\users\smdhk\anaconda3\envs\pycaret\lib\site-packages (from lightgbm>=2.3.1->pycaret[full]) (0.37.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\smdhk\anaconda3\envs\pycaret\lib\site-packages (from matplotlib->pycaret[full]) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\smdhk\anaconda3\envs\pycaret\lib\site-packages (from matplotlib->pycaret[full]) (1.4.4)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\smdhk\anaconda3\envs\pycaret\lib\site-packages (from matplotlib->pycaret[full]) (2.8.2)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\smdhk\anaconda3\envs\pycaret\lib\site-packages (from matplotlib->pycaret[full]) (4.36.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\smdhk\anaconda3\envs\pycaret\lib\site-packages (from matplotlib->pycaret[full]) (21.3)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\smdhk\anaconda3\envs\pycaret\lib\site-packages (from matplotlib->pycaret[full]) (3.0.9)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\smdhk\anaconda3\envs\pycaret\lib\site-packages (from matplotlib->pycaret[full]) (9.2.0)
# Requirement already satisfied: llvmlite<0.38,>=0.37.0rc1 in c:\users\smdhk\anaconda3\envs\pycaret\lib\site-packages (from numba<0.55->pycaret[full]) (0.37.0)
# Requirement already satisfied: alembic in c:\users\smdhk\anaconda3\envs\pycaret\lib\site-packages (from optuna>=2.2.0->pycaret[full]) (1.8.1)
# Collecting cliff
#   Using cached cliff-4.0.0-py3-none-any.whl (80 kB)
# Collecting cmaes>=0.8.2
#   Using cached cmaes-0.8.2-py3-none-any.whl (15 kB)
# Collecting colorlog
#   Using cached colorlog-6.6.0-py2.py3-none-any.whl (11 kB)
# Requirement already satisfied: tqdm in c:\users\smdhk\anaconda3\envs\pycaret\lib\site-packages (from optuna>=2.2.0->pycaret[full]) (4.64.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\smdhk\anaconda3\envs\pycaret\lib\site-packages (from pandas->pycaret[full]) (2022.2.1)
# Requirement already satisfied: visions[type_image_path]==0.7.4 in c:\users\smdhk\anaconda3\envs\pycaret\lib\site-packages (from pandas-profiling>=2.8.0->pycaret[full]) (0.7.4)
# Requirement already satisfied: phik>=0.11.1 in c:\users\smdhk\anaconda3\envs\pycaret\lib\site-packages (from pandas-profiling>=2.8.0->pycaret[full]) (0.12.2)
# Requirement already satisfied: requests>=2.24.0 in c:\users\smdhk\anaconda3\envs\pycaret\lib\site-packages (from pandas-profiling>=2.8.0->pycaret[full]) (2.28.1)
# Requirement already satisfied: multimethod>=1.4 in c:\users\smdhk\anaconda3\envs\pycaret\lib\site-packages (from pandas-profiling>=2.8.0->pycaret[full]) (1.8)
# Requirement already satisfied: htmlmin>=0.1.12 in c:\users\smdhk\anaconda3\envs\pycaret\lib\site-packages (from pandas-profiling>=2.8.0->pycaret[full]) (0.1.12)
# Requirement already satisfied: tangled-up-in-unicode==0.2.0 in c:\users\smdhk\anaconda3\envs\pycaret\lib\site-packages (from pandas-profiling>=2.8.0->pycaret[full]) (0.2.0)
# Requirement already satisfied: pydantic>=1.8.1 in c:\users\smdhk\anaconda3\envs\pycaret\lib\site-packages (from pandas-profiling>=2.8.0->pycaret[full]) (1.9.2)
# Requirement already satisfied: missingno>=0.4.2 in c:\users\smdhk\anaconda3\envs\pycaret\lib\site-packages (from pandas-profiling>=2.8.0->pycaret[full]) (0.5.1)
# Requirement already satisfied: markupsafe~=2.1.1 in c:\users\smdhk\anaconda3\envs\pycaret\lib\site-packages (from pandas-profiling>=2.8.0->pycaret[full]) (2.1.1)
# Requirement already satisfied: networkx>=2.4 in c:\users\smdhk\anaconda3\envs\pycaret\lib\site-packages (from visions[type_image_path]==0.7.4->pandas-profiling>=2.8.0->pycaret[full]) (2.8.5)
# Requirement already satisfied: attrs>=19.3.0 in c:\users\smdhk\anaconda3\envs\pycaret\lib\site-packages (from visions[type_image_path]==0.7.4->pandas-profiling>=2.8.0->pycaret[full]) (22.1.0)
# Requirement already satisfied: imagehash in c:\users\smdhk\anaconda3\envs\pycaret\lib\site-packages (from visions[type_image_path]==0.7.4->pandas-profiling>=2.8.0->pycaret[full]) (4.2.1)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\smdhk\anaconda3\envs\pycaret\lib\site-packages (from plotly>=4.4.1->pycaret[full]) (8.0.1)
# Collecting filelock
#   Downloading filelock-3.8.0-py3-none-any.whl (10 kB)
# Collecting virtualenv
#   Using cached virtualenv-20.16.3-py2.py3-none-any.whl (8.8 MB)
# Requirement already satisfied: jsonschema in c:\users\smdhk\anaconda3\envs\pycaret\lib\site-packages (from ray[tune]>=1.0.0->pycaret[full]) (4.9.1)
# Collecting click<=8.0.4,>=7.0
#   Downloading click-8.0.4-py3-none-any.whl (97 kB)
#      ---------------------------------------- 97.5/97.5 kB 5.5 MB/s eta 0:00:00
# Requirement already satisfied: aiosignal in c:\users\smdhk\anaconda3\envs\pycaret\lib\site-packages (from ray[tune]>=1.0.0->pycaret[full]) (1.2.0)
# Requirement already satisfied: frozenlist in c:\users\smdhk\anaconda3\envs\pycaret\lib\site-packages (from ray[tune]>=1.0.0->pycaret[full]) (1.3.1)
# Collecting msgpack<2.0.0,>=1.0.0
#   Downloading msgpack-1.0.4-cp38-cp38-win_amd64.whl (62 kB)
#      ---------------------------------------- 62.2/62.2 kB ? eta 0:00:00
# Collecting grpcio<=1.43.0,>=1.28.1
#   Downloading grpcio-1.43.0-cp38-cp38-win_amd64.whl (3.4 MB)
#      ---------------------------------------- 3.4/3.4 MB 7.1 MB/s eta 0:00:00
# Collecting protobuf<4.0.0,>=3.15.3
#   Downloading protobuf-3.20.1-cp38-cp38-win_amd64.whl (904 kB)
#      ------------------------------------- 904.4/904.4 kB 11.3 MB/s eta 0:00:00
# Collecting tensorboardX>=1.9
#   Using cached tensorboardX-2.5.1-py2.py3-none-any.whl (125 kB)
# Requirement already satisfied: tabulate in c:\users\smdhk\anaconda3\envs\pycaret\lib\site-packages (from ray[tune]>=1.0.0->pycaret[full]) (0.8.10)
# Collecting pyaml>=16.9
#   Using cached pyaml-21.10.1-py2.py3-none-any.whl (24 kB)
# Requirement already satisfied: wasabi<1.1.0,>=0.4.0 in c:\users\smdhk\anaconda3\envs\pycaret\lib\site-packages (from spacy<2.4.0->pycaret[full]) (0.10.1)
# Requirement already satisfied: plac<1.2.0,>=0.9.6 in c:\users\smdhk\anaconda3\envs\pycaret\lib\site-packages (from spacy<2.4.0->pycaret[full]) (1.1.3)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\smdhk\anaconda3\envs\pycaret\lib\site-packages (from spacy<2.4.0->pycaret[full]) (2.0.6)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\smdhk\anaconda3\envs\pycaret\lib\site-packages (from spacy<2.4.0->pycaret[full]) (3.0.7)
# Requirement already satisfied: thinc<7.5.0,>=7.4.1 in c:\users\smdhk\anaconda3\envs\pycaret\lib\site-packages (from spacy<2.4.0->pycaret[full]) (7.4.5)
# Requirement already satisfied: srsly<1.1.0,>=1.0.2 in c:\users\smdhk\anaconda3\envs\pycaret\lib\site-packages (from spacy<2.4.0->pycaret[full]) (1.0.5)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in c:\users\smdhk\anaconda3\envs\pycaret\lib\site-packages (from spacy<2.4.0->pycaret[full]) (0.7.8)
# Requirement already satisfied: catalogue<1.1.0,>=0.0.7 in c:\users\smdhk\anaconda3\envs\pycaret\lib\site-packages (from spacy<2.4.0->pycaret[full]) (1.0.0)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\smdhk\anaconda3\envs\pycaret\lib\site-packages (from spacy<2.4.0->pycaret[full]) (1.0.8)
# Collecting bokeh>=2.4.2
#   Using cached bokeh-2.4.3-py3-none-any.whl (18.5 MB)
# Requirement already satisfied: typing-extensions>=4.1.1 in c:\users\smdhk\anaconda3\envs\pycaret\lib\site-packages (from autoviz->pycaret[full]) (4.3.0)
# Collecting xlrd
#   Using cached xlrd-2.0.1-py2.py3-none-any.whl (96 kB)
# Collecting emoji
#   Using cached emoji-2.0.0.tar.gz (197 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting fsspec>=0.8.3
#   Downloading fsspec-2022.7.1-py3-none-any.whl (141 kB)
#      -------------------------------------- 141.2/141.2 kB 4.2 MB/s eta 0:00:00
# Collecting pyamg
#   Downloading pyamg-4.2.3-cp38-cp38-win_amd64.whl (1.4 MB)
#      ---------------------------------------- 1.4/1.4 MB 4.7 MB/s eta 0:00:00
# Collecting hvplot>=0.7.3
#   Downloading hvplot-0.8.0-py2.py3-none-any.whl (3.1 MB)
#      ---------------------------------------- 3.1/3.1 MB 8.0 MB/s eta 0:00:00
# Collecting jupyter
#   Downloading jupyter-1.0.0-py2.py3-none-any.whl (2.7 kB)
# Collecting panel~=0.12.6
#   Using cached panel-0.12.7-py2.py3-none-any.whl (12.9 MB)
# Collecting holoviews>=1.14.6
#   Downloading holoviews-1.15.0-py2.py3-none-any.whl (4.3 MB)
#      ---------------------------------------- 4.3/4.3 MB 7.3 MB/s eta 0:00:00
# Requirement already satisfied: statsmodels in c:\users\smdhk\anaconda3\envs\pycaret\lib\site-packages (from autoviz->pycaret[full]) (0.13.2)
# Requirement already satisfied: cryptography>=2.1.4 in c:\users\smdhk\anaconda3\envs\pycaret\lib\site-packages (from azure-storage-blob->pycaret[full]) (37.0.1)
# Collecting azure-core<2.0.0,>=1.23.1
#   Using cached azure_core-1.25.0-py3-none-any.whl (178 kB)
# Collecting msrest>=0.6.21
#   Using cached msrest-0.7.1-py3-none-any.whl (85 kB)
# Collecting s3transfer<0.7.0,>=0.6.0
#   Downloading s3transfer-0.6.0-py3-none-any.whl (79 kB)
#      ---------------------------------------- 79.6/79.6 kB 4.3 MB/s eta 0:00:00
# Collecting jmespath<2.0.0,>=0.7.1
#   Downloading jmespath-1.0.1-py3-none-any.whl (20 kB)
# Collecting botocore<1.28.0,>=1.27.59
#   Downloading botocore-1.27.59-py3-none-any.whl (9.1 MB)
#      ---------------------------------------- 9.1/9.1 MB 9.4 MB/s eta 0:00:00
# Collecting dataclasses>=0.6
#   Using cached dataclasses-0.6-py3-none-any.whl (14 kB)
# Collecting evidently
#   Using cached evidently-0.1.55.dev0-py3-none-any.whl (11.9 MB)
#   Using cached evidently-0.1.54.dev0-py3-none-any.whl (11.9 MB)
#   Using cached evidently-0.1.53.dev0-py3-none-any.whl (11.9 MB)
#   Using cached evidently-0.1.52.dev2-py3-none-any.whl (11.9 MB)
#   Using cached evidently-0.1.52.dev0-py3-none-any.whl (11.9 MB)
#   Using cached evidently-0.1.51.dev0-py3-none-any.whl (11.9 MB)
# Collecting dash>=2.3.1
#   Using cached dash-2.6.1-py3-none-any.whl (9.9 MB)
# Requirement already satisfied: waitress in c:\users\smdhk\anaconda3\envs\pycaret\lib\site-packages (from explainerdashboard->pycaret[full]) (2.1.2)
# Collecting oyaml
#   Using cached oyaml-1.0-py2.py3-none-any.whl (3.0 kB)
# Collecting explainerdashboard
#   Using cached explainerdashboard-0.3.8.2-py3-none-any.whl (305 kB)
# Collecting dash-bootstrap-components<1
#   Using cached dash_bootstrap_components-0.13.1-py3-none-any.whl (197 kB)
# Collecting flask-simplelogin
#   Using cached flask_simplelogin-0.1.1-py3-none-any.whl (7.2 kB)
# Collecting dash-auth
#   Using cached dash_auth-1.4.1.tar.gz (470 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting jupyter-dash
#   Using cached jupyter_dash-0.4.2-py3-none-any.whl (23 kB)
# Collecting Werkzeug<=2.0.3
#   Downloading Werkzeug-2.0.3-py3-none-any.whl (289 kB)
#      -------------------------------------- 289.2/289.2 kB 4.5 MB/s eta 0:00:00
# Collecting dtreeviz>=1.3
#   Using cached dtreeviz-1.3.7.tar.gz (62 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: cloudpickle in c:\users\smdhk\anaconda3\envs\pycaret\lib\site-packages (from shap->pycaret[full]) (2.1.0)
# Requirement already satisfied: slicer==0.0.7 in c:\users\smdhk\anaconda3\envs\pycaret\lib\site-packages (from shap->pycaret[full]) (0.0.7)
# Collecting starlette==0.19.1
#   Using cached starlette-0.19.1-py3-none-any.whl (63 kB)
# Requirement already satisfied: anyio<5,>=3.4.0 in c:\users\smdhk\anaconda3\envs\pycaret\lib\site-packages (from starlette==0.19.1->fastapi->pycaret[full]) (3.6.1)
# Collecting google-resumable-media>=2.3.2
#   Downloading google_resumable_media-2.3.3-py2.py3-none-any.whl (76 kB)
#      ---------------------------------------- 76.9/76.9 kB 4.4 MB/s eta 0:00:00
# Collecting google-auth<3.0dev,>=1.25.0
#   Downloading google_auth-2.11.0-py2.py3-none-any.whl (167 kB)
#      -------------------------------------- 167.2/167.2 kB 5.1 MB/s eta 0:00:00
# Collecting google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5
#   Downloading google_api_core-2.8.2-py3-none-any.whl (114 kB)
#      -------------------------------------- 114.6/114.6 kB 3.4 MB/s eta 0:00:00
# Collecting google-cloud-core<3.0dev,>=2.3.0
#   Downloading google_cloud_core-2.3.2-py2.py3-none-any.whl (29 kB)
# Collecting ffmpy
#   Using cached ffmpy-0.3.0.tar.gz (4.8 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting pycryptodome
#   Using cached pycryptodome-3.15.0-cp35-abi3-win_amd64.whl (1.9 MB)
# Collecting orjson
#   Downloading orjson-3.7.12-cp38-none-win_amd64.whl (199 kB)
#      -------------------------------------- 199.4/199.4 kB 4.0 MB/s eta 0:00:00
# Collecting websockets
#   Downloading websockets-10.3-cp38-cp38-win_amd64.whl (98 kB)
#      ---------------------------------------- 98.6/98.6 kB 5.5 MB/s eta 0:00:00
# Requirement already satisfied: aiohttp in c:\users\smdhk\anaconda3\envs\pycaret\lib\site-packages (from gradio->pycaret[full]) (3.8.1)
# Collecting paramiko
#   Downloading paramiko-2.11.0-py2.py3-none-any.whl (212 kB)
#      -------------------------------------- 212.9/212.9 kB 6.5 MB/s eta 0:00:00
# Collecting h11<0.13,>=0.11
#   Using cached h11-0.12.0-py3-none-any.whl (54 kB)
# Collecting httpx
#   Using cached httpx-0.23.0-py3-none-any.whl (84 kB)
# Requirement already satisfied: python-multipart in c:\users\smdhk\anaconda3\envs\pycaret\lib\site-packages (from gradio->pycaret[full]) (0.0.5)
# Collecting markdown-it-py[linkify,plugins]
#   Using cached markdown_it_py-2.1.0-py3-none-any.whl (84 kB)
# Collecting pydub
#   Using cached pydub-0.25.1-py2.py3-none-any.whl (32 kB)
# Collecting analytics-python
#   Using cached analytics_python-1.4.0-py2.py3-none-any.whl (15 kB)
# Collecting py4j
#   Downloading py4j-0.10.9.7-py2.py3-none-any.whl (200 kB)
#      -------------------------------------- 200.5/200.5 kB 6.1 MB/s eta 0:00:00
# Requirement already satisfied: future in c:\users\smdhk\anaconda3\envs\pycaret\lib\site-packages (from hyperopt->pycaret[full]) (0.18.2)
# Requirement already satisfied: docker<6,>=4.0.0 in c:\users\smdhk\anaconda3\envs\pycaret\lib\site-packages (from mlflow->pycaret[full]) (5.0.3)
# Requirement already satisfied: sqlparse<1,>=0.4.0 in c:\users\smdhk\anaconda3\envs\pycaret\lib\site-packages (from mlflow->pycaret[full]) (0.4.2)
# Requirement already satisfied: databricks-cli<1,>=0.8.7 in c:\users\smdhk\anaconda3\envs\pycaret\lib\site-packages (from mlflow->pycaret[full]) (0.17.2)
# Requirement already satisfied: entrypoints<1 in c:\users\smdhk\anaconda3\envs\pycaret\lib\site-packages (from mlflow->pycaret[full]) (0.4)
# Requirement already satisfied: querystring-parser<2 in c:\users\smdhk\anaconda3\envs\pycaret\lib\site-packages (from mlflow->pycaret[full]) (1.2.4)
# Requirement already satisfied: importlib-metadata!=4.7.0,<5,>=3.7.0 in c:\users\smdhk\anaconda3\envs\pycaret\lib\site-packages (from mlflow->pycaret[full]) (4.12.0)
# Requirement already satisfied: gitpython<4,>=2.1.0 in c:\users\smdhk\anaconda3\envs\pycaret\lib\site-packages (from mlflow->pycaret[full]) (3.1.27)
# Requirement already satisfied: prometheus-flask-exporter<1 in c:\users\smdhk\anaconda3\envs\pycaret\lib\site-packages (from mlflow->pycaret[full]) (0.20.3)
# Requirement already satisfied: Flask<3 in c:\users\smdhk\anaconda3\envs\pycaret\lib\site-packages (from mlflow->pycaret[full]) (2.2.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\smdhk\anaconda3\envs\pycaret\lib\site-packages (from nltk->pycaret[full]) (2022.8.17)
# Requirement already satisfied: numexpr in c:\users\smdhk\anaconda3\envs\pycaret\lib\site-packages (from pyLDAvis->pycaret[full]) (2.8.3)
# Requirement already satisfied: funcy in c:\users\smdhk\anaconda3\envs\pycaret\lib\site-packages (from pyLDAvis->pycaret[full]) (1.17)
# Requirement already satisfied: pynndescent>=0.5 in c:\users\smdhk\anaconda3\envs\pycaret\lib\site-packages (from umap-learn->pycaret[full]) (0.5.7)
# Requirement already satisfied: importlib-resources in c:\users\smdhk\anaconda3\envs\pycaret\lib\site-packages (from alembic->optuna>=2.2.0->pycaret[full]) (5.9.0)
# Requirement already satisfied: Mako in c:\users\smdhk\anaconda3\envs\pycaret\lib\site-packages (from alembic->optuna>=2.2.0->pycaret[full]) (1.2.1)
# Requirement already satisfied: tornado>=5.1 in c:\users\smdhk\anaconda3\envs\pycaret\lib\site-packages (from bokeh>=2.4.2->autoviz->pycaret[full]) (6.2)
# Requirement already satisfied: urllib3<1.27,>=1.25.4 in c:\users\smdhk\anaconda3\envs\pycaret\lib\site-packages (from botocore<1.28.0,>=1.27.59->boto3->pycaret[full]) (1.26.11)
# Requirement already satisfied: cffi>=1.12 in c:\users\smdhk\anaconda3\envs\pycaret\lib\site-packages (from cryptography>=2.1.4->azure-storage-blob->pycaret[full]) (1.15.1)
# Collecting flask-compress
#   Using cached Flask_Compress-1.12-py3-none-any.whl (7.9 kB)
# Collecting dash-html-components==2.0.0
#   Using cached dash_html_components-2.0.0-py3-none-any.whl (4.1 kB)
# Collecting dash-core-components==2.0.0
#   Using cached dash_core_components-2.0.0-py3-none-any.whl (3.8 kB)
# Collecting dash-table==5.0.0
#   Using cached dash_table-5.0.0-py3-none-any.whl (3.9 kB)
# Requirement already satisfied: oauthlib>=3.1.0 in c:\users\smdhk\anaconda3\envs\pycaret\lib\site-packages (from databricks-cli<1,>=0.8.7->mlflow->pycaret[full]) (3.2.0)
# Requirement already satisfied: pyjwt>=1.7.0 in c:\users\smdhk\anaconda3\envs\pycaret\lib\site-packages (from databricks-cli<1,>=0.8.7->mlflow->pycaret[full]) (2.4.0)
# Collecting pywin32==227
#   Using cached pywin32-227-cp38-cp38-win_amd64.whl (9.1 MB)
# Requirement already satisfied: websocket-client>=0.32.0 in c:\users\smdhk\anaconda3\envs\pycaret\lib\site-packages (from docker<6,>=4.0.0->mlflow->pycaret[full]) (1.3.3)
# Collecting colour
#   Using cached colour-0.1.5-py2.py3-none-any.whl (23 kB)
# Collecting pytest
#   Downloading pytest-7.1.2-py3-none-any.whl (297 kB)
#      -------------------------------------- 297.0/297.0 kB 6.1 MB/s eta 0:00:00
# Collecting Flask<3
#   Downloading Flask-2.2.1-py3-none-any.whl (101 kB)
#      -------------------------------------- 101.5/101.5 kB 2.9 MB/s eta 0:00:00
# Requirement already satisfied: itsdangerous>=2.0 in c:\users\smdhk\anaconda3\envs\pycaret\lib\site-packages (from Flask<3->mlflow->pycaret[full]) (2.1.2)
#   Downloading Flask-2.2.0-py3-none-any.whl (101 kB)
#      -------------------------------------- 101.1/101.1 kB 5.7 MB/s eta 0:00:00
#   Downloading Flask-2.1.3-py3-none-any.whl (95 kB)
#      ---------------------------------------- 95.6/95.6 kB 5.3 MB/s eta 0:00:00
# Collecting antlr4-python3-runtime>=4.10
#   Using cached antlr4-python3-runtime-4.10.tar.gz (116 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\smdhk\anaconda3\envs\pycaret\lib\site-packages (from gitpython<4,>=2.1.0->mlflow->pycaret[full]) (4.0.9)
# Collecting googleapis-common-protos<2.0dev,>=1.56.2
#   Downloading googleapis_common_protos-1.56.4-py2.py3-none-any.whl (211 kB)
#      -------------------------------------- 211.7/211.7 kB 4.3 MB/s eta 0:00:00
# Collecting pyasn1-modules>=0.2.1
#   Using cached pyasn1_modules-0.2.8-py2.py3-none-any.whl (155 kB)
# Collecting rsa<5,>=3.1.4
#   Using cached rsa-4.9-py3-none-any.whl (34 kB)
# Collecting cachetools<6.0,>=2.0.0
#   Using cached cachetools-5.2.0-py3-none-any.whl (9.3 kB)
# Collecting google-crc32c<2.0dev,>=1.0
#   Downloading google_crc32c-1.3.0-cp38-cp38-win_amd64.whl (27 kB)
# Collecting param<2.0,>=1.9.3
#   Downloading param-1.12.2-py2.py3-none-any.whl (86 kB)
#      ---------------------------------------- 86.8/86.8 kB 4.8 MB/s eta 0:00:00
# Collecting holoviews>=1.14.6
#   Downloading holoviews-1.14.9-py2.py3-none-any.whl (4.3 MB)
#      ---------------------------------------- 4.3/4.3 MB 3.9 MB/s eta 0:00:00
# Collecting pyviz-comms>=0.7.4
#   Downloading pyviz_comms-2.2.1-py2.py3-none-any.whl (42 kB)
#      ---------------------------------------- 42.9/42.9 kB 2.0 MB/s eta 0:00:00
# Collecting colorcet
#   Downloading colorcet-3.0.0-py2.py3-none-any.whl (1.6 MB)
#      ---------------------------------------- 1.6/1.6 MB 1.7 MB/s eta 0:00:00
# Requirement already satisfied: zipp>=0.5 in c:\users\smdhk\anaconda3\envs\pycaret\lib\site-packages (from importlib-metadata!=4.7.0,<5,>=3.7.0->mlflow->pycaret[full]) (3.8.1)
# Collecting SALib>=1.3.3
#   Using cached SALib-1.4.5-py2.py3-none-any.whl (756 kB)
# Collecting lime>=0.1.1.33
#   Using cached lime-0.2.0.1.tar.gz (275 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting treeinterpreter>=0.2.2
#   Using cached treeinterpreter-0.2.3-py2.py3-none-any.whl (6.0 kB)
# Collecting dill>=0.2.5
#   Using cached dill-0.3.5.1-py2.py3-none-any.whl (95 kB)
# Collecting skope-rules>=1.0.1
#   Using cached skope_rules-1.0.1-py3-none-any.whl (14 kB)
# Collecting gevent>=1.3.6
#   Downloading gevent-21.12.0-cp38-cp38-win_amd64.whl (1.6 MB)
#      ---------------------------------------- 1.6/1.6 MB 3.4 MB/s eta 0:00:00
# Collecting dash-cytoscape>=0.1.1
#   Using cached dash_cytoscape-0.3.0-py3-none-any.whl (3.6 MB)
# Requirement already satisfied: nest-asyncio in c:\users\smdhk\anaconda3\envs\pycaret\lib\site-packages (from ipykernel>=4.5.1->ipywidgets->pycaret[full]) (1.5.5)
# Requirement already satisfied: debugpy>=1.0 in c:\users\smdhk\anaconda3\envs\pycaret\lib\site-packages (from ipykernel>=4.5.1->ipywidgets->pycaret[full]) (1.6.3)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\users\smdhk\anaconda3\envs\pycaret\lib\site-packages (from ipykernel>=4.5.1->ipywidgets->pycaret[full]) (7.3.4)
# Requirement already satisfied: pyzmq>=17 in c:\users\smdhk\anaconda3\envs\pycaret\lib\site-packages (from ipykernel>=4.5.1->ipywidgets->pycaret[full]) (23.2.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\smdhk\anaconda3\envs\pycaret\lib\site-packages (from jedi>=0.16->IPython->pycaret[full]) (0.8.3)
# Collecting isodate>=0.6.0
#   Using cached isodate-0.6.1-py2.py3-none-any.whl (41 kB)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\smdhk\anaconda3\envs\pycaret\lib\site-packages (from msrest>=0.6.21->azure-storage-blob->pycaret[full]) (2022.6.15)
# Collecting requests-oauthlib>=0.5.0
#   Using cached requests_oauthlib-1.3.1-py2.py3-none-any.whl (23 kB)
# Requirement already satisfied: bleach in c:\users\smdhk\anaconda3\envs\pycaret\lib\site-packages (from panel~=0.12.6->autoviz->pycaret[full]) (5.0.1)
# Collecting pyct>=0.4.4
#   Downloading pyct-0.4.8-py2.py3-none-any.whl (15 kB)
# Collecting setuptools>=34.4.1
#   Using cached setuptools-60.10.0-py3-none-any.whl (1.1 MB)
# Collecting markdown
#   Using cached Markdown-3.4.1-py3-none-any.whl (93 kB)
# Requirement already satisfied: prometheus-client in c:\users\smdhk\anaconda3\envs\pycaret\lib\site-packages (from prometheus-flask-exporter<1->mlflow->pycaret[full]) (0.13.1)
# Requirement already satisfied: wcwidth in c:\users\smdhk\anaconda3\envs\pycaret\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->IPython->pycaret[full]) (0.2.5)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\smdhk\anaconda3\envs\pycaret\lib\site-packages (from requests>=2.24.0->pandas-profiling>=2.8.0->pycaret[full]) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\smdhk\anaconda3\envs\pycaret\lib\site-packages (from requests>=2.24.0->pandas-profiling>=2.8.0->pycaret[full]) (3.3)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\smdhk\anaconda3\envs\pycaret\lib\site-packages (from sqlalchemy->fugue>=0.6.5->pycaret[full]) (1.1.2)
# Requirement already satisfied: patsy>=0.5.2 in c:\users\smdhk\anaconda3\envs\pycaret\lib\site-packages (from statsmodels->autoviz->pycaret[full]) (0.5.2)
# Requirement already satisfied: fs in c:\users\smdhk\anaconda3\envs\pycaret\lib\site-packages (from triad>=0.6.6->fugue>=0.6.5->pycaret[full]) (2.4.16)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in c:\users\smdhk\anaconda3\envs\pycaret\lib\site-packages (from aiohttp->gradio->pycaret[full]) (4.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\smdhk\anaconda3\envs\pycaret\lib\site-packages (from aiohttp->gradio->pycaret[full]) (1.8.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\smdhk\anaconda3\envs\pycaret\lib\site-packages (from aiohttp->gradio->pycaret[full]) (6.0.2)
# Collecting monotonic>=1.5
#   Using cached monotonic-1.6-py2.py3-none-any.whl (8.2 kB)
# Collecting backoff==1.10.0
#   Using cached backoff-1.10.0-py2.py3-none-any.whl (31 kB)
# Collecting PrettyTable>=0.7.2
#   Using cached prettytable-3.3.0-py3-none-any.whl (26 kB)
# Collecting autopage>=0.4.0
#   Using cached autopage-0.5.1-py3-none-any.whl (29 kB)
# Collecting cmd2>=1.0.0
#   Using cached cmd2-2.4.2-py3-none-any.whl (147 kB)
# Collecting stevedore>=2.0.1
#   Using cached stevedore-4.0.0-py3-none-any.whl (49 kB)
# Collecting chart_studio>=1.0.0
#   Using cached chart_studio-1.1.0-py3-none-any.whl (64 kB)
# Collecting flask-seasurf
#   Using cached Flask_SeaSurf-1.1.1-py3-none-any.whl (8.4 kB)
# Collecting retrying
#   Using cached retrying-1.3.3.tar.gz (10 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting ua_parser
#   Downloading ua_parser-0.16.0-py2.py3-none-any.whl (38 kB)
# Collecting Flask-WTF<0.16.0,>=0.15.1
#   Using cached Flask_WTF-0.15.1-py2.py3-none-any.whl (13 kB)
# Collecting WTForms>=2.1
#   Using cached WTForms-3.0.1-py3-none-any.whl (136 kB)
# Requirement already satisfied: sniffio in c:\users\smdhk\anaconda3\envs\pycaret\lib\site-packages (from httpx->gradio->pycaret[full]) (1.2.0)
# Collecting rfc3986[idna2008]<2,>=1.3
#   Using cached rfc3986-1.5.0-py2.py3-none-any.whl (31 kB)
# Collecting httpcore<0.16.0,>=0.15.0
#   Using cached httpcore-0.15.0-py3-none-any.whl (68 kB)
# Requirement already satisfied: pkgutil-resolve-name>=1.3.10 in c:\users\smdhk\anaconda3\envs\pycaret\lib\site-packages (from jsonschema->ray[tune]>=1.0.0->pycaret[full]) (1.3.10)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\smdhk\anaconda3\envs\pycaret\lib\site-packages (from jsonschema->ray[tune]>=1.0.0->pycaret[full]) (0.18.1)
# Requirement already satisfied: nbconvert in c:\users\smdhk\anaconda3\envs\pycaret\lib\site-packages (from jupyter->autoviz->pycaret[full]) (6.5.3)
# Collecting qtconsole
#   Downloading qtconsole-5.3.1-py3-none-any.whl (120 kB)
#      -------------------------------------- 120.8/120.8 kB 3.5 MB/s eta 0:00:00
# Requirement already satisfied: notebook in c:\users\smdhk\anaconda3\envs\pycaret\lib\site-packages (from jupyter->autoviz->pycaret[full]) (6.4.12)
# Collecting jupyter-console
#   Downloading jupyter_console-6.4.4-py3-none-any.whl (22 kB)
# Collecting ansi2html
#   Using cached ansi2html-1.8.0-py3-none-any.whl (16 kB)
# Collecting mdurl~=0.1
#   Using cached mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Collecting linkify-it-py~=1.0
#   Using cached linkify_it_py-1.0.3-py3-none-any.whl (19 kB)
# Collecting mdit-py-plugins
#   Using cached mdit_py_plugins-0.3.0-py3-none-any.whl (43 kB)
# Collecting pynacl>=1.0.1
#   Downloading PyNaCl-1.5.0-cp36-abi3-win_amd64.whl (212 kB)
#      -------------------------------------- 212.1/212.1 kB 4.4 MB/s eta 0:00:00
# Collecting bcrypt>=3.1.3
#   Downloading bcrypt-4.0.0-cp36-abi3-win_amd64.whl (153 kB)
#      -------------------------------------- 153.1/153.1 kB 2.3 MB/s eta 0:00:00
# Requirement already satisfied: pure-eval in c:\users\smdhk\anaconda3\envs\pycaret\lib\site-packages (from stack-data->IPython->pycaret[full]) (0.2.2)
# Requirement already satisfied: executing in c:\users\smdhk\anaconda3\envs\pycaret\lib\site-packages (from stack-data->IPython->pycaret[full]) (0.10.0)
# Requirement already satisfied: asttokens in c:\users\smdhk\anaconda3\envs\pycaret\lib\site-packages (from stack-data->IPython->pycaret[full]) (2.0.8)
# Collecting distlib<1,>=0.3.5
#   Using cached distlib-0.3.5-py2.py3-none-any.whl (466 kB)
# Collecting platformdirs<3,>=2.4
#   Using cached platformdirs-2.5.2-py3-none-any.whl (14 kB)
# Requirement already satisfied: pycparser in c:\users\smdhk\anaconda3\envs\pycaret\lib\site-packages (from cffi>=1.12->cryptography>=2.1.4->azure-storage-blob->pycaret[full]) (2.21)
# Collecting pyperclip>=1.6
#   Using cached pyperclip-1.8.2.tar.gz (20 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting pyreadline3
#   Using cached pyreadline3-3.4.1-py3-none-any.whl (95 kB)
# Collecting zope.interface
#   Downloading zope.interface-5.4.0-cp38-cp38-win_amd64.whl (210 kB)
#      -------------------------------------- 210.8/210.8 kB 6.3 MB/s eta 0:00:00
# Collecting zope.event
#   Using cached zope.event-4.5.0-py2.py3-none-any.whl (6.8 kB)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\users\smdhk\anaconda3\envs\pycaret\lib\site-packages (from gitdb<5,>=4.0.1->gitpython<4,>=2.1.0->mlflow->pycaret[full]) (5.0.0)
# Requirement already satisfied: jupyter-core>=4.9.2 in c:\users\smdhk\anaconda3\envs\pycaret\lib\site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets->pycaret[full]) (4.11.1)
# Collecting scikit-image>=0.12
#   Downloading scikit_image-0.19.3-cp38-cp38-win_amd64.whl (12.2 MB)
#      ---------------------------------------- 12.2/12.2 MB 7.0 MB/s eta 0:00:00
# Collecting uc-micro-py
#   Using cached uc_micro_py-1.0.1-py3-none-any.whl (6.2 kB)
# Collecting pyasn1<0.5.0,>=0.4.6
#   Using cached pyasn1-0.4.8-py2.py3-none-any.whl (77 kB)
# Collecting pathos
#   Using cached pathos-0.2.9-py3-none-any.whl (76 kB)
# Collecting pbr!=2.1.0,>=2.0.0
#   Using cached pbr-5.10.0-py2.py3-none-any.whl (112 kB)
# Requirement already satisfied: webencodings in c:\users\smdhk\anaconda3\envs\pycaret\lib\site-packages (from bleach->panel~=0.12.6->autoviz->pycaret[full]) (0.5.1)
# Collecting brotli
#   Downloading Brotli-1.0.9-cp38-cp38-win_amd64.whl (365 kB)
#      -------------------------------------- 365.3/365.3 kB 7.6 MB/s eta 0:00:00
# Requirement already satisfied: appdirs~=1.4.3 in c:\users\smdhk\anaconda3\envs\pycaret\lib\site-packages (from fs->triad>=0.6.6->fugue>=0.6.5->pycaret[full]) (1.4.4)
# Requirement already satisfied: PyWavelets in c:\users\smdhk\anaconda3\envs\pycaret\lib\site-packages (from imagehash->visions[type_image_path]==0.7.4->pandas-profiling>=2.8.0->pycaret[full]) (1.3.0)
# Requirement already satisfied: jupyterlab-pygments in c:\users\smdhk\anaconda3\envs\pycaret\lib\site-packages (from nbconvert->jupyter->autoviz->pycaret[full]) (0.2.2)
# Requirement already satisfied: beautifulsoup4 in c:\users\smdhk\anaconda3\envs\pycaret\lib\site-packages (from nbconvert->jupyter->autoviz->pycaret[full]) (4.11.1)
# Requirement already satisfied: tinycss2 in c:\users\smdhk\anaconda3\envs\pycaret\lib\site-packages (from nbconvert->jupyter->autoviz->pycaret[full]) (1.1.1)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\users\smdhk\anaconda3\envs\pycaret\lib\site-packages (from nbconvert->jupyter->autoviz->pycaret[full]) (0.8.4)
# Requirement already satisfied: nbclient>=0.5.0 in c:\users\smdhk\anaconda3\envs\pycaret\lib\site-packages (from nbconvert->jupyter->autoviz->pycaret[full]) (0.6.6)
# Requirement already satisfied: nbformat>=5.1 in c:\users\smdhk\anaconda3\envs\pycaret\lib\site-packages (from nbconvert->jupyter->autoviz->pycaret[full]) (5.4.0)
# Requirement already satisfied: lxml in c:\users\smdhk\anaconda3\envs\pycaret\lib\site-packages (from nbconvert->jupyter->autoviz->pycaret[full]) (4.9.1)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\smdhk\anaconda3\envs\pycaret\lib\site-packages (from nbconvert->jupyter->autoviz->pycaret[full]) (1.5.0)
# Requirement already satisfied: defusedxml in c:\users\smdhk\anaconda3\envs\pycaret\lib\site-packages (from nbconvert->jupyter->autoviz->pycaret[full]) (0.7.1)
# Requirement already satisfied: argon2-cffi in c:\users\smdhk\anaconda3\envs\pycaret\lib\site-packages (from notebook->jupyter->autoviz->pycaret[full]) (21.3.0)
# Requirement already satisfied: ipython-genutils in c:\users\smdhk\anaconda3\envs\pycaret\lib\site-packages (from notebook->jupyter->autoviz->pycaret[full]) (0.2.0)
# Requirement already satisfied: Send2Trash>=1.8.0 in c:\users\smdhk\anaconda3\envs\pycaret\lib\site-packages (from notebook->jupyter->autoviz->pycaret[full]) (1.8.0)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\smdhk\anaconda3\envs\pycaret\lib\site-packages (from notebook->jupyter->autoviz->pycaret[full]) (0.15.0)
# Collecting pluggy<2.0,>=0.12
#   Downloading pluggy-1.0.0-py2.py3-none-any.whl (13 kB)
# Requirement already satisfied: tomli>=1.0.0 in c:\users\smdhk\anaconda3\envs\pycaret\lib\site-packages (from pytest->dtreeviz>=1.3->explainerdashboard->pycaret[full]) (2.0.1)
# Collecting iniconfig
#   Downloading iniconfig-1.1.1-py2.py3-none-any.whl (5.0 kB)
# Collecting py>=1.8.2
#   Downloading py-1.11.0-py2.py3-none-any.whl (98 kB)
#      ---------------------------------------- 98.7/98.7 kB ? eta 0:00:00
# Collecting atomicwrites>=1.0
#   Downloading atomicwrites-1.4.1.tar.gz (14 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting qtpy>=2.0.1
#   Downloading QtPy-2.2.0-py3-none-any.whl (82 kB)
#      ---------------------------------------- 82.3/82.3 kB 4.8 MB/s eta 0:00:00
# Requirement already satisfied: fastjsonschema in c:\users\smdhk\anaconda3\envs\pycaret\lib\site-packages (from nbformat>=5.1->nbconvert->jupyter->autoviz->pycaret[full]) (2.16.1)
# Collecting tifffile>=2019.7.26
#   Downloading tifffile-2022.8.12-py3-none-any.whl (208 kB)
#      -------------------------------------- 208.5/208.5 kB 2.1 MB/s eta 0:00:00
# Collecting imageio>=2.4.1
#   Downloading imageio-2.21.1-py3-none-any.whl (3.4 MB)
#      ---------------------------------------- 3.4/3.4 MB 3.5 MB/s eta 0:00:00
# Requirement already satisfied: pywinpty>=1.1.0 in c:\users\smdhk\anaconda3\envs\pycaret\lib\site-packages (from terminado>=0.8.3->notebook->jupyter->autoviz->pycaret[full]) (2.0.7)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\smdhk\anaconda3\envs\pycaret\lib\site-packages (from argon2-cffi->notebook->jupyter->autoviz->pycaret[full]) (21.2.0)
# Requirement already satisfied: soupsieve>1.2 in c:\users\smdhk\anaconda3\envs\pycaret\lib\site-packages (from beautifulsoup4->nbconvert->jupyter->autoviz->pycaret[full]) (2.3.2.post1)
# Collecting ppft>=1.7.6.5
#   Using cached ppft-1.7.6.5-py2.py3-none-any.whl (52 kB)
# Collecting multiprocess>=0.70.13
#   Downloading multiprocess-0.70.13-py38-none-any.whl (131 kB)
#      -------------------------------------- 131.4/131.4 kB 8.1 MB/s eta 0:00:00
# Collecting pox>=0.3.1
#   Using cached pox-0.3.1-py2.py3-none-any.whl (28 kB)
# Building wheels for collected packages: dtreeviz, fugue-sql-antlr, dash-auth, emoji, ffmpy, antlr4-python3-runtime, lime, retrying, atomicwrites, pyperclip
#   Building wheel for dtreeviz (setup.py): started
#   Building wheel for dtreeviz (setup.py): finished with status 'done'
#   Created wheel for dtreeviz: filename=dtreeviz-1.3.7-py3-none-any.whl size=68137 sha256=ac37c18cab1cc7f5e0ffb6057a16d7be640d924c75b7b10750a2c1b8b4ca730c
#   Stored in directory: c:\users\smdhk\appdata\local\pip\cache\wheels\b3\ee\0e\7dd46108f92bf77a46d1d2506e512ed898a98906daedb3c411
#   Building wheel for fugue-sql-antlr (setup.py): started
#   Building wheel for fugue-sql-antlr (setup.py): finished with status 'done'
#   Created wheel for fugue-sql-antlr: filename=fugue_sql_antlr-0.1.0-py3-none-any.whl size=177211 sha256=2afc9ba06c036625f60ce797450cdd53aef007b5cc5871ecdfb2912d8081dbaa
#   Stored in directory: c:\users\smdhk\appdata\local\pip\cache\wheels\de\da\e3\320be07862778f380920ccf0849c976ec6047cd12a068eec52
#   Building wheel for dash-auth (setup.py): started
#   Building wheel for dash-auth (setup.py): finished with status 'done'
#   Created wheel for dash-auth: filename=dash_auth-1.4.1-py3-none-any.whl size=476135 sha256=681fa3df021dcc617c76ec66b4463fa388e2948e9960d15411945a3b3b87ba5d
#   Stored in directory: c:\users\smdhk\appdata\local\pip\cache\wheels\49\39\d4\8b86e01a8b6c9fd63051de54f4ebb256e85d9759505d749c37
#   Building wheel for emoji (setup.py): started
#   Building wheel for emoji (setup.py): finished with status 'done'
#   Created wheel for emoji: filename=emoji-2.0.0-py3-none-any.whl size=193007 sha256=b41d0c0c862ae5f9c67be606b6f782f5235a6a51c59a04fb23895a232316d7bb
#   Stored in directory: c:\users\smdhk\appdata\local\pip\cache\wheels\23\a5\a8\e74bad1ceced228b6ae94dcbacc5c67df6486fd1620714e7d1
#   Building wheel for ffmpy (setup.py): started
#   Building wheel for ffmpy (setup.py): finished with status 'done'
#   Created wheel for ffmpy: filename=ffmpy-0.3.0-py3-none-any.whl size=4693 sha256=5d2875f244260006f071ee9e81fdace84b08fec95296b62cd556ee35df477f5a
#   Stored in directory: c:\users\smdhk\appdata\local\pip\cache\wheels\ff\5b\59\913b443e7369dc04b61f607a746b6f7d83fb65e2e19fcc958d
#   Building wheel for antlr4-python3-runtime (setup.py): started
#   Building wheel for antlr4-python3-runtime (setup.py): finished with status 'done'
#   Created wheel for antlr4-python3-runtime: filename=antlr4_python3_runtime-4.10-py3-none-any.whl size=144153 sha256=a913cf0bf86cab2ff1b4530c2d67f940115c9be8843249db218232747f7f54c7
#   Stored in directory: c:\users\smdhk\appdata\local\pip\cache\wheels\b6\ad\fa\3b3f55bd8f984116397a4da5b33a4f9be7df18c2be0ba972e4
#   Building wheel for lime (setup.py): started
#   Building wheel for lime (setup.py): finished with status 'done'
#   Created wheel for lime: filename=lime-0.2.0.1-py3-none-any.whl size=283839 sha256=59810566e58049fb39074e1943ee024cea040b4cc10f7df4f621d00eaa6957bb
#   Stored in directory: c:\users\smdhk\appdata\local\pip\cache\wheels\e6\a6\20\cc1e293fcdb67ede666fed293cb895395e7ecceb4467779546
#   Building wheel for retrying (setup.py): started
#   Building wheel for retrying (setup.py): finished with status 'done'
#   Created wheel for retrying: filename=retrying-1.3.3-py3-none-any.whl size=11431 sha256=2848c91649d174417af047a531c47b45ffead97ddeba5c7e2fc71cc52db335a1
#   Stored in directory: c:\users\smdhk\appdata\local\pip\cache\wheels\c4\a7\48\0a434133f6d56e878ca511c0e6c38326907c0792f67b476e56
#   Building wheel for atomicwrites (setup.py): started
#   Building wheel for atomicwrites (setup.py): finished with status 'done'
#   Created wheel for atomicwrites: filename=atomicwrites-1.4.1-py2.py3-none-any.whl size=6943 sha256=312b24588dd722e6f9e01eeeb9dfdda32dc78b741db3eba6fbf7b41647eebe48
#   Stored in directory: c:\users\smdhk\appdata\local\pip\cache\wheels\ce\24\c1\56b1ca77dda9577b75eb88d7ec50425f103ec2f6170c6e97df
#   Building wheel for pyperclip (setup.py): started
#   Building wheel for pyperclip (setup.py): finished with status 'done'
#   Created wheel for pyperclip: filename=pyperclip-1.8.2-py3-none-any.whl size=11123 sha256=3e059051fe4ac2ac8df428fe8b8d50a65ba9fc5ebc52f9b0809152d69be62b15
#   Stored in directory: c:\users\smdhk\appdata\local\pip\cache\wheels\7f\1a\65\84ff8c386bec21fca6d220ea1f5498a0367883a78dd5ba6122
# Successfully built dtreeviz fugue-sql-antlr dash-auth emoji ffmpy antlr4-python3-runtime lime retrying atomicwrites pyperclip
# Installing collected packages: ua_parser, treeinterpreter, rfc3986, pywin32, pyreadline3, pyperclip, pydub, pyasn1, py4j, msgpack, monotonic, interpret-core, iniconfig, ffmpy, emoji, distlib, dataclasses, dash-table, dash-html-components, dash-core-components, colour, brotli, antlr4-python3-runtime, xlrd, WTForms, Werkzeug, websockets, uc-micro-py, tifffile, setuptools, rsa, retrying, pycryptodome, pyasn1-modules, pyarrow, pyaml, py, protobuf, PrettyTable, ppft, pox, pluggy, platformdirs, pbr, param, oyaml, orjson, mdurl, m2cgen, jmespath, isodate, imageio, h11, grpcio, graphviz, google-crc32c, fsspec, filelock, dill, colorlog, cmd2, cmaes, click, cachetools, bcrypt, backoff, autopage, atomicwrites, ansi2html, zope.interface, zope.event, xgboost, virtualenv, tensorboardX, stevedore, starlette, scikit-image, requests-oauthlib, qtpy, pyviz-comms, pytest, pynacl, pyct, pyamg, multiprocess, markdown-it-py, markdown, linkify-it-py, hyperopt, httpcore, googleapis-common-protos, google-resumable-media, google-auth, Flask, chart_studio, botocore, bokeh, azure-core, analytics-python, triad, skope-rules, scikit-optimize, s3transfer, ray, pathos, paramiko, panel, msrest, mdit-py-plugins, lime, httpx, google-api-core, gevent, Flask-WTF, flask-seasurf, flask-compress, fastapi, fairlearn, dtreeviz, colorcet, cliff, catboost, SALib, optuna, holoviews, google-cloud-core, fugue-sql-antlr, flask-simplelogin, evidently, dash, boto3, azure-storage-blob, adagio, tune-sklearn, qtconsole, qpd, jupyter-dash, jupyter-console, hvplot, gradio, google-cloud-storage, dash-cytoscape, dash-bootstrap-components, dash-auth, fugue, explainerdashboard, jupyter, interpret, autoviz
#   Attempting uninstall: pywin32
#     Found existing installation: pywin32 303
#     Uninstalling pywin32-303:
#       Successfully uninstalled pywin32-303
#   Rolling back uninstall of pywin32
#   Moving to c:\users\smdhk\anaconda3\envs\pycaret\lib\site-packages\__pycache__\pythoncom.cpython-38.pyc
#    from C:\Users\smdhk\AppData\Local\Temp\pip-uninstall-uach37_j\pythoncom.cpython-38.pyc
#   Moving to c:\users\smdhk\anaconda3\envs\pycaret\lib\site-packages\adodbapi
#    from C:\Users\smdhk\anaconda3\envs\pycaret\Lib\site-packages\~dodbapi
#   Moving to c:\users\smdhk\anaconda3\envs\pycaret\lib\site-packages\isapi
#    from C:\Users\smdhk\anaconda3\envs\pycaret\Lib\site-packages\~sapi
#   Moving to c:\users\smdhk\anaconda3\envs\pycaret\lib\site-packages\pythoncom.py
#    from C:\Users\smdhk\AppData\Local\Temp\pip-uninstall-l4_zy__2\pythoncom.py
#   Moving to c:\users\smdhk\anaconda3\envs\pycaret\lib\site-packages\pythonwin
#    from C:\Users\smdhk\anaconda3\envs\pycaret\Lib\site-packages\~ythonwin
#   Moving to c:\users\smdhk\anaconda3\envs\pycaret\lib\site-packages\pywin32-303-py3.8.egg-info
#    from C:\Users\smdhk\anaconda3\envs\pycaret\Lib\site-packages\~ywin32-303-py3.8.egg-info
#   Moving to c:\users\smdhk\anaconda3\envs\pycaret\lib\site-packages\win32\lib\
#    from C:\Users\smdhk\anaconda3\envs\pycaret\Lib\site-packages\win32\~ib
#   Moving to c:\users\smdhk\anaconda3\envs\pycaret\lib\site-packages\win32com
#    from C:\Users\smdhk\anaconda3\envs\pycaret\Lib\site-packages\~in32com
#   Moving to c:\users\smdhk\anaconda3\envs\pycaret\lib\site-packages\win32comext
#    from C:\Users\smdhk\anaconda3\envs\pycaret\Lib\site-packages\~in32comext
# ERROR: Could not install packages due to an OSError: [WinError 5] 액세스가 거부되었습니다: 'C:\\Users\\smdhk\\anaconda3\\envs\\pycaret\\Lib\\site-packages\\win32\\_win32sysloader.pyd'
# Consider using the `--user` option or check the permissions.

# %%
lgb = create_model('lightgbm')
plot_model(lgb, plot = 'confusion_matrix', save=True)
lgb # 해당 모델 미지원
# Out:
# LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#                importance_type='split', learning_rate=0.1, max_depth=-1,
#                min_child_samples=20, min_child_weight=0.001, min_split_gain=0.0,
#                n_estimators=100, n_jobs=-1, num_leaves=31, objective=None,
#                random_state=123, reg_alpha=0.0, reg_lambda=0.0, silent='warn',
#                subsample=1.0, subsample_for_bin=200000, subsample_freq=0)

# %%
create_model('lightgbm')
# Out:
# <style type="text/css">
# #T_ffa96_row10_col0, #T_ffa96_row10_col1, #T_ffa96_row10_col2, #T_ffa96_row10_col3, #T_ffa96_row10_col4, #T_ffa96_row10_col5, #T_ffa96_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_ffa96">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ffa96_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_ffa96_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_ffa96_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_ffa96_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_ffa96_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_ffa96_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_ffa96_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ffa96_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ffa96_row0_col0" class="data row0 col0" >0.5845</td>
#       <td id="T_ffa96_row0_col1" class="data row0 col1" >0.0000</td>
#       <td id="T_ffa96_row0_col2" class="data row0 col2" >0.0699</td>
#       <td id="T_ffa96_row0_col3" class="data row0 col3" >0.6256</td>
#       <td id="T_ffa96_row0_col4" class="data row0 col4" >0.5971</td>
#       <td id="T_ffa96_row0_col5" class="data row0 col5" >0.0342</td>
#       <td id="T_ffa96_row0_col6" class="data row0 col6" >0.0346</td>
#     </tr>
#     <tr>
#       <th id="T_ffa96_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_ffa96_row1_col0" class="data row1 col0" >0.7141</td>
#       <td id="T_ffa96_row1_col1" class="data row1 col1" >0.0000</td>
#       <td id="T_ffa96_row1_col2" class="data row1 col2" >0.0719</td>
#       <td id="T_ffa96_row1_col3" class="data row1 col3" >0.6670</td>
#       <td id="T_ffa96_row1_col4" class="data row1 col4" >0.6787</td>
#       <td id="T_ffa96_row1_col5" class="data row1 col5" >0.1079</td>
#       <td id="T_ffa96_row1_col6" class="data row1 col6" >0.1142</td>
#     </tr>
#     <tr>
#       <th id="T_ffa96_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_ffa96_row2_col0" class="data row2 col0" >0.6501</td>
#       <td id="T_ffa96_row2_col1" class="data row2 col1" >0.0000</td>
#       <td id="T_ffa96_row2_col2" class="data row2 col2" >0.0396</td>
#       <td id="T_ffa96_row2_col3" class="data row2 col3" >0.6185</td>
#       <td id="T_ffa96_row2_col4" class="data row2 col4" >0.6299</td>
#       <td id="T_ffa96_row2_col5" class="data row2 col5" >0.0232</td>
#       <td id="T_ffa96_row2_col6" class="data row2 col6" >0.0236</td>
#     </tr>
#     <tr>
#       <th id="T_ffa96_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_ffa96_row3_col0" class="data row3 col0" >0.6081</td>
#       <td id="T_ffa96_row3_col1" class="data row3 col1" >0.0000</td>
#       <td id="T_ffa96_row3_col2" class="data row3 col2" >0.0546</td>
#       <td id="T_ffa96_row3_col3" class="data row3 col3" >0.6236</td>
#       <td id="T_ffa96_row3_col4" class="data row3 col4" >0.6132</td>
#       <td id="T_ffa96_row3_col5" class="data row3 col5" >0.0503</td>
#       <td id="T_ffa96_row3_col6" class="data row3 col6" >0.0506</td>
#     </tr>
#     <tr>
#       <th id="T_ffa96_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_ffa96_row4_col0" class="data row4 col0" >0.6266</td>
#       <td id="T_ffa96_row4_col1" class="data row4 col1" >0.0000</td>
#       <td id="T_ffa96_row4_col2" class="data row4 col2" >0.0636</td>
#       <td id="T_ffa96_row4_col3" class="data row4 col3" >0.6365</td>
#       <td id="T_ffa96_row4_col4" class="data row4 col4" >0.6279</td>
#       <td id="T_ffa96_row4_col5" class="data row4 col5" >0.0665</td>
#       <td id="T_ffa96_row4_col6" class="data row4 col6" >0.0666</td>
#     </tr>
#     <tr>
#       <th id="T_ffa96_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_ffa96_row5_col0" class="data row5 col0" >0.6717</td>
#       <td id="T_ffa96_row5_col1" class="data row5 col1" >0.0000</td>
#       <td id="T_ffa96_row5_col2" class="data row5 col2" >0.0622</td>
#       <td id="T_ffa96_row5_col3" class="data row5 col3" >0.6575</td>
#       <td id="T_ffa96_row5_col4" class="data row5 col4" >0.6601</td>
#       <td id="T_ffa96_row5_col5" class="data row5 col5" >0.1079</td>
#       <td id="T_ffa96_row5_col6" class="data row5 col6" >0.1088</td>
#     </tr>
#     <tr>
#       <th id="T_ffa96_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_ffa96_row6_col0" class="data row6 col0" >0.7024</td>
#       <td id="T_ffa96_row6_col1" class="data row6 col1" >0.0000</td>
#       <td id="T_ffa96_row6_col2" class="data row6 col2" >0.0623</td>
#       <td id="T_ffa96_row6_col3" class="data row6 col3" >0.6445</td>
#       <td id="T_ffa96_row6_col4" class="data row6 col4" >0.6638</td>
#       <td id="T_ffa96_row6_col5" class="data row6 col5" >0.0801</td>
#       <td id="T_ffa96_row6_col6" class="data row6 col6" >0.0844</td>
#     </tr>
#     <tr>
#       <th id="T_ffa96_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_ffa96_row7_col0" class="data row7 col0" >0.7215</td>
#       <td id="T_ffa96_row7_col1" class="data row7 col1" >0.0000</td>
#       <td id="T_ffa96_row7_col2" class="data row7 col2" >0.0590</td>
#       <td id="T_ffa96_row7_col3" class="data row7 col3" >0.6320</td>
#       <td id="T_ffa96_row7_col4" class="data row7 col4" >0.6686</td>
#       <td id="T_ffa96_row7_col5" class="data row7 col5" >0.1111</td>
#       <td id="T_ffa96_row7_col6" class="data row7 col6" >0.1201</td>
#     </tr>
#     <tr>
#       <th id="T_ffa96_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_ffa96_row8_col0" class="data row8 col0" >0.7117</td>
#       <td id="T_ffa96_row8_col1" class="data row8 col1" >0.0000</td>
#       <td id="T_ffa96_row8_col2" class="data row8 col2" >0.0881</td>
#       <td id="T_ffa96_row8_col3" class="data row8 col3" >0.6859</td>
#       <td id="T_ffa96_row8_col4" class="data row8 col4" >0.6887</td>
#       <td id="T_ffa96_row8_col5" class="data row8 col5" >0.1634</td>
#       <td id="T_ffa96_row8_col6" class="data row8 col6" >0.1674</td>
#     </tr>
#     <tr>
#       <th id="T_ffa96_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_ffa96_row9_col0" class="data row9 col0" >0.7106</td>
#       <td id="T_ffa96_row9_col1" class="data row9 col1" >0.0000</td>
#       <td id="T_ffa96_row9_col2" class="data row9 col2" >0.0412</td>
#       <td id="T_ffa96_row9_col3" class="data row9 col3" >0.6161</td>
#       <td id="T_ffa96_row9_col4" class="data row9 col4" >0.6553</td>
#       <td id="T_ffa96_row9_col5" class="data row9 col5" >0.0235</td>
#       <td id="T_ffa96_row9_col6" class="data row9 col6" >0.0265</td>
#     </tr>
#     <tr>
#       <th id="T_ffa96_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_ffa96_row10_col0" class="data row10 col0" >0.6701</td>
#       <td id="T_ffa96_row10_col1" class="data row10 col1" >0.0000</td>
#       <td id="T_ffa96_row10_col2" class="data row10 col2" >0.0612</td>
#       <td id="T_ffa96_row10_col3" class="data row10 col3" >0.6407</td>
#       <td id="T_ffa96_row10_col4" class="data row10 col4" >0.6483</td>
#       <td id="T_ffa96_row10_col5" class="data row10 col5" >0.0768</td>
#       <td id="T_ffa96_row10_col6" class="data row10 col6" >0.0797</td>
#     </tr>
#     <tr>
#       <th id="T_ffa96_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_ffa96_row11_col0" class="data row11 col0" >0.0474</td>
#       <td id="T_ffa96_row11_col1" class="data row11 col1" >0.0000</td>
#       <td id="T_ffa96_row11_col2" class="data row11 col2" >0.0136</td>
#       <td id="T_ffa96_row11_col3" class="data row11 col3" >0.0218</td>
#       <td id="T_ffa96_row11_col4
# LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#                importance_type='split', learning_rate=0.1, max_depth=-1,
#                min_child_samples=20, min_child_weight=0.001, min_split_gain=0.0,
#                n_estimators=100, n_jobs=-1, num_leaves=31, objective=None,
#                random_state=123, reg_alpha=0.0, reg_lambda=0.0, silent='warn',
#                subsample=1.0, subsample_for_bin=200000, subsample_freq=0)

# %%
rf = create_model(estimator = 'rf')
plot_model(rf, plot = 'confusion_matrix', save=True)
# Out:
# 'Confusion Matrix.png'

# %%
create_model(estimator = 'dt')
# Out:
# <style type="text/css">
# #T_ce756_row10_col0, #T_ce756_row10_col1, #T_ce756_row10_col2, #T_ce756_row10_col3, #T_ce756_row10_col4, #T_ce756_row10_col5, #T_ce756_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_ce756">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ce756_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_ce756_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_ce756_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_ce756_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_ce756_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_ce756_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_ce756_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ce756_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ce756_row0_col0" class="data row0 col0" >0.9758</td>
#       <td id="T_ce756_row0_col1" class="data row0 col1" >0.0000</td>
#       <td id="T_ce756_row0_col2" class="data row0 col2" >0.8719</td>
#       <td id="T_ce756_row0_col3" class="data row0 col3" >0.9758</td>
#       <td id="T_ce756_row0_col4" class="data row0 col4" >0.9757</td>
#       <td id="T_ce756_row0_col5" class="data row0 col5" >0.9381</td>
#       <td id="T_ce756_row0_col6" class="data row0 col6" >0.9381</td>
#     </tr>
#     <tr>
#       <th id="T_ce756_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_ce756_row1_col0" class="data row1 col0" >0.9717</td>
#       <td id="T_ce756_row1_col1" class="data row1 col1" >0.0000</td>
#       <td id="T_ce756_row1_col2" class="data row1 col2" >0.8656</td>
#       <td id="T_ce756_row1_col3" class="data row1 col3" >0.9717</td>
#       <td id="T_ce756_row1_col4" class="data row1 col4" >0.9716</td>
#       <td id="T_ce756_row1_col5" class="data row1 col5" >0.9277</td>
#       <td id="T_ce756_row1_col6" class="data row1 col6" >0.9277</td>
#     </tr>
#     <tr>
#       <th id="T_ce756_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_ce756_row2_col0" class="data row2 col0" >0.9744</td>
#       <td id="T_ce756_row2_col1" class="data row2 col1" >0.0000</td>
#       <td id="T_ce756_row2_col2" class="data row2 col2" >0.8243</td>
#       <td id="T_ce756_row2_col3" class="data row2 col3" >0.9747</td>
#       <td id="T_ce756_row2_col4" class="data row2 col4" >0.9744</td>
#       <td id="T_ce756_row2_col5" class="data row2 col5" >0.9346</td>
#       <td id="T_ce756_row2_col6" class="data row2 col6" >0.9346</td>
#     </tr>
#     <tr>
#       <th id="T_ce756_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_ce756_row3_col0" class="data row3 col0" >0.9753</td>
#       <td id="T_ce756_row3_col1" class="data row3 col1" >0.0000</td>
#       <td id="T_ce756_row3_col2" class="data row3 col2" >0.8958</td>
#       <td id="T_ce756_row3_col3" class="data row3 col3" >0.9759</td>
#       <td id="T_ce756_row3_col4" class="data row3 col4" >0.9755</td>
#       <td id="T_ce756_row3_col5" class="data row3 col5" >0.9369</td>
#       <td id="T_ce756_row3_col6" class="data row3 col6" >0.9369</td>
#     </tr>
#     <tr>
#       <th id="T_ce756_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_ce756_row4_col0" class="data row4 col0" >0.9722</td>
#       <td id="T_ce756_row4_col1" class="data row4 col1" >0.9550</td>
#       <td id="T_ce756_row4_col2" class="data row4 col2" >0.7774</td>
#       <td id="T_ce756_row4_col3" class="data row4 col3" >0.9724</td>
#       <td id="T_ce756_row4_col4" class="data row4 col4" >0.9721</td>
#       <td id="T_ce756_row4_col5" class="data row4 col5" >0.9289</td>
#       <td id="T_ce756_row4_col6" class="data row4 col6" >0.9289</td>
#     </tr>
#     <tr>
#       <th id="T_ce756_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_ce756_row5_col0" class="data row5 col0" >0.9713</td>
#       <td id="T_ce756_row5_col1" class="data row5 col1" >0.0000</td>
#       <td id="T_ce756_row5_col2" class="data row5 col2" >0.8076</td>
#       <td id="T_ce756_row5_col3" class="data row5 col3" >0.9714</td>
#       <td id="T_ce756_row5_col4" class="data row5 col4" >0.9712</td>
#       <td id="T_ce756_row5_col5" class="data row5 col5" >0.9265</td>
#       <td id="T_ce756_row5_col6" class="data row5 col6" >0.9265</td>
#     </tr>
#     <tr>
#       <th id="T_ce756_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_ce756_row6_col0" class="data row6 col0" >0.9743</td>
#       <td id="T_ce756_row6_col1" class="data row6 col1" >0.0000</td>
#       <td id="T_ce756_row6_col2" class="data row6 col2" >0.8180</td>
#       <td id="T_ce756_row6_col3" class="data row6 col3" >0.9746</td>
#       <td id="T_ce756_row6_col4" class="data row6 col4" >0.9743</td>
#       <td id="T_ce756_row6_col5" class="data row6 col5" >0.9343</td>
#       <td id="T_ce756_row6_col6" class="data row6 col6" >0.9343</td>
#     </tr>
#     <tr>
#       <th id="T_ce756_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_ce756_row7_col0" class="data row7 col0" >0.9740</td>
#       <td id="T_ce756_row7_col1" class="data row7 col1" >0.0000</td>
#       <td id="T_ce756_row7_col2" class="data row7 col2" >0.7933</td>
#       <td id="T_ce756_row7_col3" class="data row7 col3" >0.9745</td>
#       <td id="T_ce756_row7_col4" class="data row7 col4" >0.9742</td>
#       <td id="T_ce756_row7_col5" class="data row7 col5" >0.9335</td>
#       <td id="T_ce756_row7_col6" class="data row7 col6" >0.9335</td>
#     </tr>
#     <tr>
#       <th id="T_ce756_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_ce756_row8_col0" class="data row8 col0" >0.9762</td>
#       <td id="T_ce756_row8_col1" class="data row8 col1" >0.0000</td>
#       <td id="T_ce756_row8_col2" class="data row8 col2" >0.8323</td>
#       <td id="T_ce756_row8_col3" class="data row8 col3" >0.9757</td>
#       <td id="T_ce756_row8_col4" class="data row8 col4" >0.9758</td>
#       <td id="T_ce756_row8_col5" class="data row8 col5" >0.9392</td>
#       <td id="T_ce756_row8_col6" class="data row8 col6" >0.9392</td>
#     </tr>
#     <tr>
#       <th id="T_ce756_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_ce756_row9_col0" class="data row9 col0" >0.9720</td>
#       <td id="T_ce756_row9_col1" class="data row9 col1" >0.0000</td>
#       <td id="T_ce756_row9_col2" class="data row9 col2" >0.8412</td>
#       <td id="T_ce756_row9_col3" class="data row9 col3" >0.9726</td>
#       <td id="T_ce756_row9_col4" class="data row9 col4" >0.9722</td>
#       <td id="T_ce756_row9_col5" class="data row9 col5" >0.9285</td>
#       <td id="T_ce756_row9_col6" class="data row9 col6" >0.9285</td>
#     </tr>
#     <tr>
#       <th id="T_ce756_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_ce756_row10_col0" class="data row10 col0" >0.9737</td>
#       <td id="T_ce756_row10_col1" class="data row10 col1" >0.0955</td>
#       <td id="T_ce756_row10_col2" class="data row10 col2" >0.8327</td>
#       <td id="T_ce756_row10_col3" class="data row10 col3" >0.9739</td>
#       <td id="T_ce756_row10_col4" class="data row10 col4" >0.9737</td>
#       <td id="T_ce756_row10_col5" class="data row10 col5" >0.9328</td>
#       <td id="T_ce756_row10_col6" class="data row10 col6" >0.9328</td>
#     </tr>
#     <tr>
#       <th id="T_ce756_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_ce756_row11_col0" class="data row11 col0" >0.0017</td>
#       <td id="T_ce756_row11_col1" class="data row11 col1" >0.2865</td>
#       <td id="T_ce756_row11_col2" class="data row11 col2" >0.0349</td>
#       <td id="T_ce756_row11_col3" class="data row11 col3" >0.0017</td>
#       <td id="T_ce756_row11_col4
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=None, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=123, splitter='best')

# %%
dt = create_model(estimator = 'dt')
plot_model(dt, save=True)
# Out:
# <style type="text/css">
# #T_3c03b_row10_col0, #T_3c03b_row10_col1, #T_3c03b_row10_col2, #T_3c03b_row10_col3, #T_3c03b_row10_col4, #T_3c03b_row10_col5, #T_3c03b_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_3c03b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3c03b_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_3c03b_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_3c03b_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_3c03b_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_3c03b_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_3c03b_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_3c03b_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3c03b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_3c03b_row0_col0" class="data row0 col0" >0.9758</td>
#       <td id="T_3c03b_row0_col1" class="data row0 col1" >0.0000</td>
#       <td id="T_3c03b_row0_col2" class="data row0 col2" >0.8719</td>
#       <td id="T_3c03b_row0_col3" class="data row0 col3" >0.9758</td>
#       <td id="T_3c03b_row0_col4" class="data row0 col4" >0.9757</td>
#       <td id="T_3c03b_row0_col5" class="data row0 col5" >0.9381</td>
#       <td id="T_3c03b_row0_col6" class="data row0 col6" >0.9381</td>
#     </tr>
#     <tr>
#       <th id="T_3c03b_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_3c03b_row1_col0" class="data row1 col0" >0.9717</td>
#       <td id="T_3c03b_row1_col1" class="data row1 col1" >0.0000</td>
#       <td id="T_3c03b_row1_col2" class="data row1 col2" >0.8656</td>
#       <td id="T_3c03b_row1_col3" class="data row1 col3" >0.9717</td>
#       <td id="T_3c03b_row1_col4" class="data row1 col4" >0.9716</td>
#       <td id="T_3c03b_row1_col5" class="data row1 col5" >0.9277</td>
#       <td id="T_3c03b_row1_col6" class="data row1 col6" >0.9277</td>
#     </tr>
#     <tr>
#       <th id="T_3c03b_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_3c03b_row2_col0" class="data row2 col0" >0.9744</td>
#       <td id="T_3c03b_row2_col1" class="data row2 col1" >0.0000</td>
#       <td id="T_3c03b_row2_col2" class="data row2 col2" >0.8243</td>
#       <td id="T_3c03b_row2_col3" class="data row2 col3" >0.9747</td>
#       <td id="T_3c03b_row2_col4" class="data row2 col4" >0.9744</td>
#       <td id="T_3c03b_row2_col5" class="data row2 col5" >0.9346</td>
#       <td id="T_3c03b_row2_col6" class="data row2 col6" >0.9346</td>
#     </tr>
#     <tr>
#       <th id="T_3c03b_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_3c03b_row3_col0" class="data row3 col0" >0.9753</td>
#       <td id="T_3c03b_row3_col1" class="data row3 col1" >0.0000</td>
#       <td id="T_3c03b_row3_col2" class="data row3 col2" >0.8958</td>
#       <td id="T_3c03b_row3_col3" class="data row3 col3" >0.9759</td>
#       <td id="T_3c03b_row3_col4" class="data row3 col4" >0.9755</td>
#       <td id="T_3c03b_row3_col5" class="data row3 col5" >0.9369</td>
#       <td id="T_3c03b_row3_col6" class="data row3 col6" >0.9369</td>
#     </tr>
#     <tr>
#       <th id="T_3c03b_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_3c03b_row4_col0" class="data row4 col0" >0.9722</td>
#       <td id="T_3c03b_row4_col1" class="data row4 col1" >0.9550</td>
#       <td id="T_3c03b_row4_col2" class="data row4 col2" >0.7774</td>
#       <td id="T_3c03b_row4_col3" class="data row4 col3" >0.9724</td>
#       <td id="T_3c03b_row4_col4" class="data row4 col4" >0.9721</td>
#       <td id="T_3c03b_row4_col5" class="data row4 col5" >0.9289</td>
#       <td id="T_3c03b_row4_col6" class="data row4 col6" >0.9289</td>
#     </tr>
#     <tr>
#       <th id="T_3c03b_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_3c03b_row5_col0" class="data row5 col0" >0.9713</td>
#       <td id="T_3c03b_row5_col1" class="data row5 col1" >0.0000</td>
#       <td id="T_3c03b_row5_col2" class="data row5 col2" >0.8076</td>
#       <td id="T_3c03b_row5_col3" class="data row5 col3" >0.9714</td>
#       <td id="T_3c03b_row5_col4" class="data row5 col4" >0.9712</td>
#       <td id="T_3c03b_row5_col5" class="data row5 col5" >0.9265</td>
#       <td id="T_3c03b_row5_col6" class="data row5 col6" >0.9265</td>
#     </tr>
#     <tr>
#       <th id="T_3c03b_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_3c03b_row6_col0" class="data row6 col0" >0.9743</td>
#       <td id="T_3c03b_row6_col1" class="data row6 col1" >0.0000</td>
#       <td id="T_3c03b_row6_col2" class="data row6 col2" >0.8180</td>
#       <td id="T_3c03b_row6_col3" class="data row6 col3" >0.9746</td>
#       <td id="T_3c03b_row6_col4" class="data row6 col4" >0.9743</td>
#       <td id="T_3c03b_row6_col5" class="data row6 col5" >0.9343</td>
#       <td id="T_3c03b_row6_col6" class="data row6 col6" >0.9343</td>
#     </tr>
#     <tr>
#       <th id="T_3c03b_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_3c03b_row7_col0" class="data row7 col0" >0.9740</td>
#       <td id="T_3c03b_row7_col1" class="data row7 col1" >0.0000</td>
#       <td id="T_3c03b_row7_col2" class="data row7 col2" >0.7933</td>
#       <td id="T_3c03b_row7_col3" class="data row7 col3" >0.9745</td>
#       <td id="T_3c03b_row7_col4" class="data row7 col4" >0.9742</td>
#       <td id="T_3c03b_row7_col5" class="data row7 col5" >0.9335</td>
#       <td id="T_3c03b_row7_col6" class="data row7 col6" >0.9335</td>
#     </tr>
#     <tr>
#       <th id="T_3c03b_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_3c03b_row8_col0" class="data row8 col0" >0.9762</td>
#       <td id="T_3c03b_row8_col1" class="data row8 col1" >0.0000</td>
#       <td id="T_3c03b_row8_col2" class="data row8 col2" >0.8323</td>
#       <td id="T_3c03b_row8_col3" class="data row8 col3" >0.9757</td>
#       <td id="T_3c03b_row8_col4" class="data row8 col4" >0.9758</td>
#       <td id="T_3c03b_row8_col5" class="data row8 col5" >0.9392</td>
#       <td id="T_3c03b_row8_col6" class="data row8 col6" >0.9392</td>
#     </tr>
#     <tr>
#       <th id="T_3c03b_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_3c03b_row9_col0" class="data row9 col0" >0.9720</td>
#       <td id="T_3c03b_row9_col1" class="data row9 col1" >0.0000</td>
#       <td id="T_3c03b_row9_col2" class="data row9 col2" >0.8412</td>
#       <td id="T_3c03b_row9_col3" class="data row9 col3" >0.9726</td>
#       <td id="T_3c03b_row9_col4" class="data row9 col4" >0.9722</td>
#       <td id="T_3c03b_row9_col5" class="data row9 col5" >0.9285</td>
#       <td id="T_3c03b_row9_col6" class="data row9 col6" >0.9285</td>
#     </tr>
#     <tr>
#       <th id="T_3c03b_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_3c03b_row10_col0" class="data row10 col0" >0.9737</td>
#       <td id="T_3c03b_row10_col1" class="data row10 col1" >0.0955</td>
#       <td id="T_3c03b_row10_col2" class="data row10 col2" >0.8327</td>
#       <td id="T_3c03b_row10_col3" class="data row10 col3" >0.9739</td>
#       <td id="T_3c03b_row10_col4" class="data row10 col4" >0.9737</td>
#       <td id="T_3c03b_row10_col5" class="data row10 col5" >0.9328</td>
#       <td id="T_3c03b_row10_col6" class="data row10 col6" >0.9328</td>
#     </tr>
#     <tr>
#       <th id="T_3c03b_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_3c03b_row11_col0" class="data row11 col0" >0.0017</td>
#       <td id="T_3c03b_row11_col1" class="data row11 col1" >0.2865</td>
#       <td id="T_3c03b_row11_col2" class="data row11 col2" >0.0349</td>
#       <td id="T_3c03b_row11_col3" class="data row11 col3" >0.0017</td>
#       <td id="T_3c03b_row11_col4
# IntProgress(value=0, description='Processing: ', max=5)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [9], in <cell line: 2>()
#       1 dt = create_model(estimator = 'dt')
# ----> 2 plot_model(dt, save=True)
#
# File ~\anaconda3\envs\pycaret\lib\site-packages\pycaret\classification.py:1685, in plot_model(estimator, plot, scale, save, fold, fit_kwargs, plot_kwargs, groups, use_train_data, verbose, display_format)
#    1567 def plot_model(
#    1568     estimator,
#    1569     plot: str = "auc",
#    (...)
#    1578     display_format: Optional[str] = None,
#    1579 ) -> str:
#    1581     """
#    1582     This function analyzes the performance of a trained model on holdout set.
#    1583     It may require re-training the model in certain cases.
#    (...)
#    1682
#    1683     """
# -> 1685     return pycaret.internal.tabular.plot_model(
#    1686         estimator=estimator,
#    1687         plot=plot,
#    1688         scale=scale,
#    1689         save=save,
#    1690         fold=fold,
#    1691         fit_kwargs=fit_kwargs,
#    1692         plot_kwargs=plot_kwargs,
#    1693         groups=groups,
#    1694         verbose=verbose,
#    1695         use_train_data=use_train_data,
#    1696         system=True,
#    1697         display_format=display_format,
#    1698     )
#
# File ~\anaconda3\envs\pycaret\lib\site-packages\pycaret\internal\tabular.py:7712, in plot_model(estimator, plot, scale, save, fold, fit_kwargs, plot_kwargs, groups, feature_name, label, use_train_data, verbose, system, display, display_format, is_in_evaluate)
#    7709     logger.info("Visual Rendered Successfully")
#    7711 # execute the plot method
# -> 7712 ret = locals()[plot]()
#    7713 if ret:
#    7714     plot_filename = ret
#
# File ~\anaconda3\envs\pycaret\lib\site-packages\pycaret\internal\tabular.py:6833, in plot_model.<locals>.auc()
#    6827     encoder_dictionary = None
#    6829 visualizer = ROCAUC(
#    6830     pipeline_with_model, encoder=encoder_dictionary, **plot_kwargs
#    6831 )
# -> 6833 show_yellowbrick_plot(
#    6834     visualizer=visualizer,
#    6835     X_train=data_X,
#    6836     y_train=data_y,
#    6837     X_test=test_X,
#    6838     y_test=test_y,
#    6839     name=plot_name,
#    6840     scale=scale,
#    6841     save=save,
#    6842     fit_kwargs=fit_kwargs,
#    6843     groups=groups,
#    6844     display=display,
#    6845     display_format=display_format,
#    6846 )
#
# File ~\anaconda3\envs\pycaret\lib\site-packages\pycaret\internal\plots\yellowbrick.py:107, in show_yellowbrick_plot(visualizer, X_train, y_train, X_test, y_test, name, handle_train, handle_test, scale, save, fit_kwargs, groups, display, display_format, **kwargs)
#     105 elif handle_test == "score":
#     106     logger.info("Scoring test/hold-out set")
# --> 107     visualizer.score(X_test, y_test)
#     109 display.move_progress()
#     110 display.clear_output()
#
# File ~\anaconda3\envs\pycaret\lib\site-packages\yellowbrick\classifier\rocauc.py:334, in ROCAUC.score(self, X, y)
#     332 # Compute micro average
#     333 if self.micro:
# --> 334     self._score_micro_average(y, y_pred, classes, n_classes)
#     336 # Compute macro average
#     337 if self.macro:
#
# File ~\anaconda3\envs\pycaret\lib\site-packages\yellowbrick\classifier\rocauc.py:490, in ROCAUC._score_micro_average(self, y, y_pred, classes, n_classes)
#     487     y = np.hstack((1 - y, y))
#     489 # Compute micro-average
# --> 490 self.fpr[MICRO], self.tpr[MICRO], _ = roc_curve(y.ravel(), y_pred.ravel())
#     491 self.roc_auc[MICRO] = auc(self.fpr[MICRO], self.tpr[MICRO])
#
# File ~\anaconda3\envs\pycaret\lib\site-packages\sklearn\utils\validation.py:72, in _deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#      67     warnings.warn("Pass {} as keyword args. From version 0.25 "
#      68                   "passing these as positional arguments will "
#      69                   "result in an error".format(", ".join(args_msg)),
#      70                   FutureWarning)
#      71 kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 72 return f(**kwargs)
#
# File ~\anaconda3\envs\pycaret\lib\site-packages\sklearn\metrics\_ranking.py:775, in roc_curve(y_true, y_score, pos_label, sample_weight, drop_intermediate)
#     690 @_deprecate_positional_args
#     691 def roc_curve(y_true, y_score, *, pos_label=None, sample_weight=None,
#     692               drop_intermediate=True):
#     693     """Compute Receiver operating characteristic (ROC)
#     694
#     695     Note: this implementation is restricted to the binary classification task.
#    (...)
#     773
#     774     """
# --> 775     fps, tps, thresholds = _binary_clf_curve(
#     776         y_true, y_score, pos_label=pos_label, sample_weight=sample_weight)
#     778     # Attempt to drop thresholds corresponding to points in between and
#     779     # collinear with other points. These are always suboptimal and do not
#     780     # appear on a plotted ROC curve (and thus do not affect the AUC).
#    (...)
#     785     # but does not drop more complicated cases like fps = [1, 3, 7],
#     786     # tps = [1, 2, 4]; there is no harm in keeping too many thresholds.
#     787     if drop_intermediate and len(fps) > 2:
#
# File ~\anaconda3\envs\pycaret\lib\site-packages\sklearn\metrics\_ranking.py:541, in _binary_clf_curve(y_true, y_score, pos_label, sample_weight)
#     537 if not (y_type == "binary" or
#     538         (y_type == "multiclass" and pos_label is not None)):
#     539     raise ValueError("{0} format is not supported".format(y_type))
# --> 541 check_consistent_length(y_true, y_score, sample_weight)
#     542 y_true = column_or_1d(y_true)
#     543 y_score = column_or_1d(y_score)
#
# File ~\anaconda3\envs\pycaret\lib\site-packages\sklearn\utils\validation.py:255, in check_consistent_length(*arrays)
#     253 uniques = np.unique(lengths)
#     254 if len(uniques) > 1:
# --> 255     raise ValueError("Found input variables with inconsistent numbers of"
#     256                      " samples: %r" % [int(l) for l in lengths])
#
# ValueError: Found input variables with inconsistent numbers of samples: [798028, 826529]

# %%
lr = create_model('lr')
plot_model(lr, save=True)

# %%
#pip install shap
# Out:
# Collecting shap
#   Downloading shap-0.41.0-cp38-cp38-win_amd64.whl (435 kB)
#      -------------------------------------- 435.6/435.6 kB 3.0 MB/s eta 0:00:00
# Requirement already satisfied: scipy in c:\users\smdhk\anaconda3\envs\pycaret\lib\site-packages (from shap) (1.5.4)
# Requirement already satisfied: numba in c:\users\smdhk\anaconda3\envs\pycaret\lib\site-packages (from shap) (0.54.1)
# Requirement already satisfied: tqdm>4.25.0 in c:\users\smdhk\anaconda3\envs\pycaret\lib\site-packages (from shap) (4.64.0)
# Requirement already satisfied: scikit-learn in c:\users\smdhk\anaconda3\envs\pycaret\lib\site-packages (from shap) (0.23.2)
# Requirement already satisfied: numpy in c:\users\smdhk\anaconda3\envs\pycaret\lib\site-packages (from shap) (1.19.5)
# Requirement already satisfied: pandas in c:\users\smdhk\anaconda3\envs\pycaret\lib\site-packages (from shap) (1.4.3)
# Requirement already satisfied: packaging>20.9 in c:\users\smdhk\anaconda3\envs\pycaret\lib\site-packages (from shap) (21.3)
# Requirement already satisfied: cloudpickle in c:\users\smdhk\anaconda3\envs\pycaret\lib\site-packages (from shap) (2.1.0)
# Collecting slicer==0.0.7
#   Using cached slicer-0.0.7-py3-none-any.whl (14 kB)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\smdhk\anaconda3\envs\pycaret\lib\site-packages (from packaging>20.9->shap) (3.0.9)
# Requirement already satisfied: colorama in c:\users\smdhk\anaconda3\envs\pycaret\lib\site-packages (from tqdm>4.25.0->shap) (0.4.5)
# Requirement already satisfied: llvmlite<0.38,>=0.37.0rc1 in c:\users\smdhk\anaconda3\envs\pycaret\lib\site-packages (from numba->shap) (0.37.0)
# Requirement already satisfied: setuptools in c:\users\smdhk\anaconda3\envs\pycaret\lib\site-packages (from numba->shap) (65.1.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\smdhk\anaconda3\envs\pycaret\lib\site-packages (from pandas->shap) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\smdhk\anaconda3\envs\pycaret\lib\site-packages (from pandas->shap) (2022.2.1)
# Requirement already satisfied: joblib>=0.11 in c:\users\smdhk\anaconda3\envs\pycaret\lib\site-packages (from scikit-learn->shap) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\smdhk\anaconda3\envs\pycaret\lib\site-packages (from scikit-learn->shap) (3.1.0)
# Requirement already satisfied: six>=1.5 in c:\users\smdhk\anaconda3\envs\pycaret\lib\site-packages (from python-dateutil>=2.8.1->pandas->shap) (1.16.0)
# Installing collected packages: slicer, shap
# Successfully installed shap-0.41.0 slicer-0.0.7
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt

def get_font_family():
    """
    시스템 환경에 따른 기본 폰트명을 반환하는 함수
    """
    import platform
    system_name = platform.system()

    if system_name == "Darwin" :
        font_family = "AppleGothic"
    elif system_name == "Windows":
        font_family = "Malgun Gothic"
    else:
        # Linux(colab)
        # !apt-get install fonts-nanum -qq  > /dev/null
        # !fc-cache -fv

        import matplotlib as mpl
        mpl.font_manager._rebuild()
        findfont = mpl.font_manager.fontManager.findfont
        mpl.font_manager.findfont = findfont
        mpl.backends.backend_agg.findfont = findfont

        font_family = "NanumBarunGothic"
    return font_family
# 시각화를 위한 폰트설정
# 위에서 만든 함수를 통해 시스템 폰트를 불러와서 font_family라는 변수에 할당합니다.
plt.style.use("ggplot")

font_family = get_font_family()
# 폰트설정
plt.rc("font", family=font_family)
# 마이너스 폰트 설정
plt.rc("axes", unicode_minus=False)
# 그래프에 retina display 적용
# from IPython.display import set_matplotlib_formats
# set_matplotlib_formats("retina")

# %config InlineBackend.figure_format = 'retina'

# %%
import shap
interpret_model(dt, plot='summary', save=True)
interpret_model(dt, plot = 'reason', observation = 10, save=True)

# %%
evaluate_model(dt)

# %%
from sklearn.model_selection import train_test_split


X = df2.drop(['광고'], axis=1)
y = df2['광고']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=2021)

model = XGBRegressor()
model.fit(X_train, y_train)

shap.initjs()
explainer = shap.TreeExplainer(model)
shap_values = explainer.shap_values(X_train)
shap.initjs()
shap.force_plot(explainer.expected_value, shap_values, X_train)
