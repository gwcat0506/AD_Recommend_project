# %%
import pandas as pd

# 매치시킬 대여소 근처 역 데이터 로드
match = pd.read_csv('./close_station.csv')
match.head(5)
# Out:
#    Unnamed: 0   번호 대여소근처역
# 0           0  102     망원
# 1           1  103     망원
# 2           2  104     합정
# 3           3  105     합정
# 4           4  106     합정

# %%
del match['Unnamed: 0']

# %%
match
# Out:
#         번호 대여소근처역
# 0      102     망원
# 1      103     망원
# 2      104     합정
# 3      105     합정
# 4      106     합정
# ...    ...    ...
# 2648  5851    신도림
# 2649  5852    신도림
# 2650  5853    여의도
# 2651  5854    여의도
# 2652  5855    여의도
#
# [2653 rows x 2 columns]

# %%
# 대여소 근처 역 데이터 로드
data = pd.read_csv('./전처리완료.csv')
data.head(5)
# Out:
#    Unnamed: 0        대여일자  대여시간  대여소번호                대여소명 대여구분코드   성별 연령대코드  \
# 0           0  2022-06-01     0    742    742. 등촌역 5번 출구 뒤    정기권  NaN   10대
# 1           1  2022-06-01     0   2059      2059. 보라매공원 정문    정기권  NaN   10대
# 2           2  2022-06-01     0   1349  1349. 월계2교 버스정류장 앞    정기권  NaN   10대
# 3           3  2022-06-01     0    750     750. 연의근린공원 건너편    정기권  NaN   10대
# 4           4  2022-06-01     0    755  755. 목동1단지아파트 상가 앞    정기권  NaN   10대
#
#    이용건수    운동량   탄소량  이동거리(M)  이용시간(분)  주말 요일
# 0     1  48.30  0.46  1999.70       10  평일  수
# 1     1  27.47  0.23   991.00        9  평일  수
# 2     1  20.63  0.20   868.17        3  평일  수
# 3     1  13.97  0.13   560.00        4  평일  수
# 4     1  12.15  0.14   590.00        3  평일  수

# %%
del data['Unnamed: 0']

# %%
df_merge = pd.merge(data,match,left_on='대여소번호',right_on='번호',how='left')
df_merge
# Out:
#                대여일자  대여시간  대여소번호                 대여소명 대여구분코드 성별 연령대코드  이용건수  \
# 0        2022-06-01     0    742     742. 등촌역 5번 출구 뒤    정기권  N   10대     1
# 1        2022-06-01     0   2059       2059. 보라매공원 정문    정기권  N   10대     1
# 2        2022-06-01     0   1349   1349. 월계2교 버스정류장 앞    정기권  N   10대     1
# 3        2022-06-01     0    750      750. 연의근린공원 건너편    정기권  N   10대     1
# 4        2022-06-01     0    755   755. 목동1단지아파트 상가 앞    정기권  N   10대     1
# ...             ...   ...    ...                  ...    ... ..   ...   ...
# 3704323  2022-06-30    23   4765      4765. 동대문디자인플라자    정기권  M     N     1
# 3704324  2022-06-30    23   4813          4813. 망우지구대    정기권  M     N     1
# 3704325  2022-06-30    23   4564          4564. 63스퀘어    정기권  M     N     1
# 3704326  2022-06-30    23    263       263. 근로자회관 사거리    정기권  M     N     1
# 3704327  2022-06-30    23   1308  1308. 안암로터리 버스정류장 앞    정기권  M     N     1
#
# ...

# %%
del df_merge['번호']

# %%
df_merge
# Out:
#                대여일자  대여시간  대여소번호                 대여소명 대여구분코드 성별 연령대코드  이용건수  \
# 0        2022-06-01     0    742     742. 등촌역 5번 출구 뒤    정기권  N   10대     1
# 1        2022-06-01     0   2059       2059. 보라매공원 정문    정기권  N   10대     1
# 2        2022-06-01     0   1349   1349. 월계2교 버스정류장 앞    정기권  N   10대     1
# 3        2022-06-01     0    750      750. 연의근린공원 건너편    정기권  N   10대     1
# 4        2022-06-01     0    755   755. 목동1단지아파트 상가 앞    정기권  N   10대     1
# ...             ...   ...    ...                  ...    ... ..   ...   ...
# 3704323  2022-06-30    23   4765      4765. 동대문디자인플라자    정기권  M     N     1
# 3704324  2022-06-30    23   4813          4813. 망우지구대    정기권  M     N     1
# 3704325  2022-06-30    23   4564          4564. 63스퀘어    정기권  M     N     1
# 3704326  2022-06-30    23    263       263. 근로자회관 사거리    정기권  M     N     1
# 3704327  2022-06-30    23   1308  1308. 안암로터리 버스정류장 앞    정기권  M     N     1
#
#            운동량   탄소량  이동거리(M)  이용시간(분)  주말 요일 대여소근처역
# ...

# %% [markdown]
# ### 동, 상권, 산업종류 최종 병합 ###

# %%
dong = pd.read_csv('./상권분석,위경도,동.csv', encoding = 'cp949')
dong.head(5)
# Out:
#    Unnamed: 0  소재지   번호         위도          경도     동                산업종류
# 0           0  마포구  102  37.555649  126.910629   서교동  사업시설관리 및 사업지원 서비스업
# 1           1  마포구  103  37.554951  126.910835  망원1동                 건설업
# 2           2  마포구  104  37.550629  126.914986   서교동  사업시설관리 및 사업지원 서비스업
# 3           3  마포구  105  37.550007  126.914825   서교동  사업시설관리 및 사업지원 서비스업
# 4           4  마포구  106  37.548645  126.912826   합정동            금융 및 보험업

# %%
del dong['Unnamed: 0']

# %%
df_merge['대여소번호'].value_counts()
# Out:
# 4217     9364
# 2715     9046
# 2102     8943
# 502      8587
# 207      8107
#          ...
# 9998        6
# 5082        4
# 2391        4
# 9979        4
# 99998       1
# Name: 대여소번호, Length: 2638, dtype: int64

# %%
dong['번호'].value_counts()
# Out:
# 4406    2
# 4876    1
# 2608    1
# 2610    1
# 563     1
#        ..
# 3311    1
# 1264    1
# 1266    1
# 1268    1
# 2041    1
# Name: 번호, Length: 2653, dtype: int64

# %%
df_merge2 = pd.merge(df_merge,dong,left_on='대여소번호',right_on='번호',how='left')
df_merge2
# Out:
#                대여일자  대여시간  대여소번호                 대여소명 대여구분코드 성별 연령대코드  이용건수  \
# 0        2022-06-01     0    742     742. 등촌역 5번 출구 뒤    정기권  N   10대     1
# 1        2022-06-01     0   2059       2059. 보라매공원 정문    정기권  N   10대     1
# 2        2022-06-01     0   1349   1349. 월계2교 버스정류장 앞    정기권  N   10대     1
# 3        2022-06-01     0    750      750. 연의근린공원 건너편    정기권  N   10대     1
# 4        2022-06-01     0    755   755. 목동1단지아파트 상가 앞    정기권  N   10대     1
# ...             ...   ...    ...                  ...    ... ..   ...   ...
# 3705472  2022-06-30    23   4765      4765. 동대문디자인플라자    정기권  M     N     1
# 3705473  2022-06-30    23   4813          4813. 망우지구대    정기권  M     N     1
# 3705474  2022-06-30    23   4564          4564. 63스퀘어    정기권  M     N     1
# 3705475  2022-06-30    23    263       263. 근로자회관 사거리    정기권  M     N     1
# 3705476  2022-06-30    23   1308  1308. 안암로터리 버스정류장 앞    정기권  M     N     1
#
# ...

# %%
df_merge2.isna().sum()
# Out:
# 대여일자          0
# 대여시간          0
# 대여소번호         0
# 대여소명          0
# 대여구분코드        0
# 성별            0
# 연령대코드         0
# 이용건수          0
# 운동량           0
# 탄소량           0
# 이동거리(M)       0
# 이용시간(분)       0
# 주말            0
# 요일            0
# 대여소근처역     7464
# 소재지        7464
# 번호         7464
# 위도         7464
# 경도         7464
# 동          7464
# 산업종류       7464
# dtype: int64

# %%
df4 = df_merge2.copy()

# %%
df3 = df_merge2[(df_merge2['대여소근처역'].isnull())|(df_merge2['소재지'].isnull())|(df_merge2['번호'].isnull())]
df3
# Out:
#                대여일자  대여시간  대여소번호            대여소명 대여구분코드 성별 연령대코드  이용건수  \
# 169      2022-06-01     0   9999            상담센터    정기권  N   20대     1
# 193      2022-06-01     0   3219  3219.영등포역 1번출구    정기권  N   20대     1
# 1517     2022-06-01     0   3219  3219.영등포역 1번출구    정기권  M   20대     1
# 1684     2022-06-01     0    210       210. IFC몰    정기권  M   20대     1
# 3745     2022-06-01     0    305     305. 종로구청 옆    일일권  M   30대     1
# ...             ...   ...    ...             ...    ... ..   ...   ...
# 3702318  2022-06-30    21   3219  3219.영등포역 1번출구    정기권  M   40대     1
# 3702366  2022-06-30    22   3219  3219.영등포역 1번출구    정기권  N   10대     1
# 3703193  2022-06-30    22   3219  3219.영등포역 1번출구    정기권  M   50대     1
# 3705402  2022-06-30    23   9999            상담센터    정기권  M   40대     1
# 3705405  2022-06-30    23   3219  3219.영등포역 1번출구    정기권  M   40대     1
#
#              운동량   탄소량  ...  이용시간(분)  주말 요일 대여소근처역  소재지  번호  위도  경도    동 산업종류
# ...

# %%
df4
# Out:
#                대여일자  대여시간  대여소번호                 대여소명 대여구분코드 성별 연령대코드  이용건수  \
# 0        2022-06-01     0    742     742. 등촌역 5번 출구 뒤    정기권  N   10대     1
# 1        2022-06-01     0   2059       2059. 보라매공원 정문    정기권  N   10대     1
# 2        2022-06-01     0   1349   1349. 월계2교 버스정류장 앞    정기권  N   10대     1
# 3        2022-06-01     0    750      750. 연의근린공원 건너편    정기권  N   10대     1
# 4        2022-06-01     0    755   755. 목동1단지아파트 상가 앞    정기권  N   10대     1
# ...             ...   ...    ...                  ...    ... ..   ...   ...
# 3705472  2022-06-30    23   4765      4765. 동대문디자인플라자    정기권  M     N     1
# 3705473  2022-06-30    23   4813          4813. 망우지구대    정기권  M     N     1
# 3705474  2022-06-30    23   4564          4564. 63스퀘어    정기권  M     N     1
# 3705475  2022-06-30    23    263       263. 근로자회관 사거리    정기권  M     N     1
# 3705476  2022-06-30    23   1308  1308. 안암로터리 버스정류장 앞    정기권  M     N     1
#
# ...

# %%
df4.dropna(axis=0, inplace=True)

# %%
df4.to_csv('final_final.csv', index = False)
